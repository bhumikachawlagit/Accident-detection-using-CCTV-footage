# %% [markdown]
# # 0. Imports

# %%
# for data handling and manipulation:
import pandas as pd
import numpy as np

# for os handling
import os

# for pre-processing
from sklearn.preprocessing import StandardScaler

# import the classifiers to fit:
from sklearn.ensemble import RandomForestClassifier

# import metrics
from sklearn.metrics import fbeta_score, classification_report, accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, roc_auc_score, auc, ConfusionMatrixDisplay, make_scorer

# for tabulating results
from tabulate import tabulate

# for visualizations
import seaborn as sns
import matplotlib.pyplot as plt

# for handling warnings
import warnings

# for hyper-parameter tuning
from skopt import BayesSearchCV
from skopt.space import Integer, Real
from sklearn.model_selection import GridSearchCV

# %%
# Reading the train, test and validation data into this notebook 

X_train_gray = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\X_train_gray.csv').drop(columns = ['Unnamed: 0'], axis = 1)
X_train_gray = X_train_gray.to_numpy()

y_train = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\y_train.csv').drop(columns = ['Unnamed: 0'], axis = 1)
y_train = y_train.to_numpy(dtype = 'int64').flatten()

X_val_gray = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\X_val_gray.csv').drop(columns = ['Unnamed: 0'], axis = 1)
X_val_gray = X_val_gray.to_numpy()

y_val = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\y_val.csv').drop(columns = ['Unnamed: 0'], axis = 1)
y_val = y_val.to_numpy(dtype = 'int64').flatten()

X_test_gray = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\X_test_gray.csv').drop(columns = ['Unnamed: 0'], axis = 1)
X_test_gray = X_test_gray.to_numpy()

y_test = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\y_test.csv').drop(columns = ['Unnamed: 0'], axis = 1)
y_test = y_test.to_numpy(dtype = 'int64').flatten()

# %%
X_train_gray.shape, y_train.shape, X_val_gray.shape, y_val.shape, X_test_gray.shape, y_test.shape
# Out:
# ((791, 98), (791,), (98, 98), (98,), (100, 98), (100,))

# %%
X_final_train_gray = np.concatenate((X_train_gray, X_val_gray), axis = 0)
y_train_final = np.concatenate((y_train, y_val), axis = 0)

# %% [markdown]
# ## Function to calculate metrics

# %%
def calculate_metrics(y_pred, y_true, normalize = False):
    
    with warnings.catch_warnings():
        
        warnings.filterwarnings('ignore')
        # calculate accuracy:
        temp = round(accuracy_score(y_true, y_pred),2)
        print('Accuracy in detecting Accident class: {}'.format(temp))
        print('\n------------------------------------------------------------------------------------------\n')
        
        my_data = []
        cr = classification_report(y_true, y_pred, output_dict = True)

        # calculate precision:
        my_data.append(['Precision',round(cr['0']['precision'],2), round(cr['1']['precision'],2)])

        # calculate recall:
        my_data.append(['Recall',round(cr['0']['recall'],2), round(cr['1']['recall'],2)])

        # f1-score:
        my_data.append(['f1-score',round(cr['0']['f1-score'],2), round(cr['1']['f1-score'],2)])

        head = ['Metric','Non-Accident images','Accident images']

        print(tabulate(my_data, headers = head, tablefmt = 'grid'))
        print('\n------------------------------------------------------------------------------------------\n')

        # calculate sensitivity (recall of positive class for binary classification)
        temp = str(round(cr['1']['recall'],2))
        print('Sensitivity/ ability to correctly classifiy to Accident class is: {}'.format(temp))
    
        # calculate specificity (recall of negative class for binary classification)
        temp = str(round(cr['0']['recall'],2))
        print('Specificity/ ability to correctly classifiy to Non-Accident class is: {}'.format(temp))
        print('\n------------------------------------------------------------------------------------------\n')

        # calculate f1-beta score:
        print('Fbeta score with beta = 1.5 is: {}'.format(str(round(fbeta_score(y_true, y_pred,beta = 1.4),2))))
        print('\n------------------------------------------------------------------------------------------\n')

        # Confusion matrix:

        if normalize == False:
            cm = confusion_matrix(y_true, y_pred)
            disp = ConfusionMatrixDisplay(cm, display_labels = ["Non-Accident", 'Accident'])
            disp.plot()
            plt.title('Confusion Matrix')
            plt.show()
            print('\n------------------------------------------------------------------------------------------\n')
        else:
            cm = confusion_matrix(y_true, y_pred, normalize='all')
            disp = ConfusionMatrixDisplay(cm, display_labels = ["Non-Accident", 'Accident'])
            disp.plot()
            plt.title('Confusion Matrix')
            plt.show()
            print('\n------------------------------------------------------------------------------------------\n')

        # ROC curve:
        fpr, tpr, thresholds = roc_curve(y_true, y_pred)
        plt.plot(fpr, tpr, marker = 'o')
        plt.xlabel('% of Non-Accidents incorrectly classified')
        plt.ylabel('% of Accidents correctly classified')
        plt.title('ROC Curve')
        plt.show()
        print('\n------------------------------------------------------------------------------------------\n')
        temp = round(auc(fpr, tpr),2)
        print('AUC score is: {}'.format(temp))

    return

# %% [markdown]
# # Fitting a Decision Tree

# %% [markdown]
# ## On grayscale images

# %% [markdown]
# ## Scale the data

# %%
scaler = StandardScaler()
X_train_gray_sc = scaler.fit_transform(X_final_train_gray)
X_test_gray_sc = scaler.transform(X_test_gray)

# %%
X_train_gray_sc.shape, X_test_gray_sc.shape
# Out:
# ((889, 98), (100, 98))

# %% [markdown]
# ### Let's formally do hyper-parameter tuning, using Bayes Optimization and Grid Search. The default parameters are also an option to use for both Bayes and Grid search CV, if they indeed have the best generalizing capability, then it will get detected.

# %%
parameters = {'n_estimators': Integer(10,200, 'uniform'),'criterion' : ['gini', 'entropy', 'log_loss'], 'max_depth': Integer(2,1e10,prior='uniform'),
              'min_samples_split': Integer(2, 10, prior='uniform'), 'min_samples_leaf': Integer(1, 10, prior='uniform'),
              'min_weight_fraction_leaf':Real(0,0.5,prior='uniform'), 'max_features':[None,'sqrt','log2'],
              'max_leaf_nodes': Integer(5, 30, prior='uniform'), 'min_impurity_decrease':Real(0, 2, 'uniform'),
              'ccp_alpha':Real(0,1,'uniform'), 'max_samples': Real(0.2,1,'uniform')} 
fbeta_scorer = make_scorer(fbeta_score, beta = 1.4)

# %%
opt = BayesSearchCV(RandomForestClassifier(random_state = 5000, class_weight= {0:1, 1:1.5}), parameters, n_iter = 200, scoring = fbeta_scorer, verbose = 5, random_state = 5000, cv = 3)

np.int = int  # numpy doesn't have int attribute now, to avoid an error in existing code, need to use int in place of this.

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    opt.fit(X_train_gray_sc, y_train_final)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8521957323049895, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=18, max_samples=0.47327133481828765, min_impurity_decrease=1.989590144429143, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.0646968663559281, n_estimators=195;, score=0.723 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.8521957323049895, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=18, max_samples=0.47327133481828765, min_impurity_decrease=1.989590144429143, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.0646968663559281, n_estimators=195;, score=0.721 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.8521957323049895, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=18, max_samples=0.47327133481828765, min_impurity_decrease=1.989590144429143, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.0646968663559281, n_estimators=195;, score=0.721 total time=   0.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.6159027912677043, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=27, max_samples=0.8232840144259346, min_impurity_decrease=0.3455643740578512, min_samples_leaf=4, min_samples_split=2, min_weight_fraction_leaf=0.17527712703505435, n_estimators=25;, score=0.723 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.6159027912677043, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=27, max_samples=0.8232840144259346, min_impurity_decrease=0.3455643740578512, min_samples_leaf=4, min_samples_split=2, min_weight_fraction_leaf=0.17527712703505435, n_estimators=25;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.6159027912677043, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=27, max_samples=0.8232840144259346, min_impurity_decrease=0.3455643740578512, min_samples_leaf=4, min_samples_split=2, min_weight_fraction_leaf=0.17527712703505435, n_estimators=25;, score=0.721 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9597329302645083, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.7607005626258649, min_impurity_decrease=1.7978269850501591, min_samples_leaf=8, min_samples_split=4, min_weight_fraction_leaf=0.07503649519214318, n_estimators=76;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.9597329302645083, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.7607005626258649, min_impurity_decrease=1.7978269850501591, min_samples_leaf=8, min_samples_split=4, min_weight_fraction_leaf=0.07503649519214318, n_estimators=76;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.9597329302645083, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.7607005626258649, min_impurity_decrease=1.7978269850501591, min_samples_leaf=8, min_samples_split=4, min_weight_fraction_leaf=0.07503649519214318, n_estimators=76;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.01596295260258274, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=26, max_samples=0.8928358573585766, min_impurity_decrease=1.546017269635014, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.1815688155362141, n_estimators=152;, score=0.723 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.01596295260258274, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=26, max_samples=0.8928358573585766, min_impurity_decrease=1.546017269635014, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.1815688155362141, n_estimators=152;, score=0.721 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.01596295260258274, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=26, max_samples=0.8928358573585766, min_impurity_decrease=1.546017269635014, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.1815688155362141, n_estimators=152;, score=0.721 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9169093057166782, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=8, max_samples=0.3284055947350754, min_impurity_decrease=1.043179366902375, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.387950476649709, n_estimators=87;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.9169093057166782, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=8, max_samples=0.3284055947350754, min_impurity_decrease=1.043179366902375, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.387950476649709, n_estimators=87;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.9169093057166782, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=8, max_samples=0.3284055947350754, min_impurity_decrease=1.043179366902375, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.387950476649709, n_estimators=87;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.4860784517570129, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=7, max_samples=0.8740948188107918, min_impurity_decrease=0.28723954953695735, min_samples_leaf=9, min_samples_split=9, min_weight_fraction_leaf=0.09134250689054098, n_estimators=80;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.4860784517570129, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=7, max_samples=0.8740948188107918, min_impurity_decrease=0.28723954953695735, min_samples_leaf=9, min_samples_split=9, min_weight_fraction_leaf=0.09134250689054098, n_estimators=80;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.4860784517570129, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=7, max_samples=0.8740948188107918, min_impurity_decrease=0.28723954953695735, min_samples_leaf=9, min_samples_split=9, min_weight_fraction_leaf=0.09134250689054098, n_estimators=80;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.3650025221738032, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=8, max_samples=0.4358952963638712, min_impurity_decrease=0.6129398367918107, min_samples_leaf=10, min_samples_split=8, min_weight_fraction_leaf=0.373479306650842, n_estimators=165;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.3650025221738032, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=8, max_samples=0.4358952963638712, min_impurity_decrease=0.6129398367918107, min_samples_leaf=10, min_samples_split=8, min_weight_fraction_leaf=0.373479306650842, n_estimators=165;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.3650025221738032, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=8, max_samples=0.4358952963638712, min_impurity_decrease=0.6129398367918107, min_samples_leaf=10, min_samples_split=8, min_weight_fraction_leaf=0.373479306650842, n_estimators=165;, score=0.721 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.27911391973795013, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=18, max_samples=0.7154571214606096, min_impurity_decrease=1.1676626639796757, min_samples_leaf=5, min_samples_split=8, min_weight_fraction_leaf=0.14849121241071309, n_estimators=69;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.27911391973795013, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=18, max_samples=0.7154571214606096, min_impurity_decrease=1.1676626639796757, min_samples_leaf=5, min_samples_split=8, min_weight_fraction_leaf=0.14849121241071309, n_estimators=69;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.27911391973795013, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=18, max_samples=0.7154571214606096, min_impurity_decrease=1.1676626639796757, min_samples_leaf=5, min_samples_split=8, min_weight_fraction_leaf=0.14849121241071309, n_estimators=69;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8499984257164044, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=25, max_samples=0.8143654541302632, min_impurity_decrease=1.0602073581161284, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.21406694440723206, n_estimators=89;, score=0.723 total time=   1.4s
# [CV 2/3] END ccp_alpha=0.8499984257164044, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=25, max_samples=0.8143654541302632, min_impurity_decrease=1.0602073581161284, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.21406694440723206, n_estimators=89;, score=0.721 total time=   1.1s
# [CV 3/3] END ccp_alpha=0.8499984257164044, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=25, max_samples=0.8143654541302632, min_impurity_decrease=1.0602073581161284, min_samples_leaf=10, min_samples_split=5, min_weight_fraction_leaf=0.21406694440723206, n_estimators=89;, score=0.721 total time=   1.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.34360856641960197, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=12, max_samples=0.46993062262894236, min_impurity_decrease=0.32691054013518067, min_samples_leaf=6, min_samples_split=3, min_weight_fraction_leaf=0.28983572597695983, n_estimators=167;, score=0.723 total time=   1.6s
# [CV 2/3] END ccp_alpha=0.34360856641960197, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=12, max_samples=0.46993062262894236, min_impurity_decrease=0.32691054013518067, min_samples_leaf=6, min_samples_split=3, min_weight_fraction_leaf=0.28983572597695983, n_estimators=167;, score=0.721 total time=   1.5s
# [CV 3/3] END ccp_alpha=0.34360856641960197, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=12, max_samples=0.46993062262894236, min_impurity_decrease=0.32691054013518067, min_samples_leaf=6, min_samples_split=3, min_weight_fraction_leaf=0.28983572597695983, n_estimators=167;, score=0.721 total time=   1.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.849737314573242, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, max_samples=0.8941143897650534, min_impurity_decrease=1.182313905953281, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.4011331827892172, n_estimators=42;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.849737314573242, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, max_samples=0.8941143897650534, min_impurity_decrease=1.182313905953281, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.4011331827892172, n_estimators=42;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.849737314573242, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, max_samples=0.8941143897650534, min_impurity_decrease=1.182313905953281, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.4011331827892172, n_estimators=42;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.4788099554942822, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=25, max_samples=0.6114853037370218, min_impurity_decrease=1.6920238875493374, min_samples_leaf=8, min_samples_split=9, min_weight_fraction_leaf=0.46447537861230825, n_estimators=133;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.4788099554942822, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=25, max_samples=0.6114853037370218, min_impurity_decrease=1.6920238875493374, min_samples_leaf=8, min_samples_split=9, min_weight_fraction_leaf=0.46447537861230825, n_estimators=133;, score=0.721 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.4788099554942822, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=25, max_samples=0.6114853037370218, min_impurity_decrease=1.6920238875493374, min_samples_leaf=8, min_samples_split=9, min_weight_fraction_leaf=0.46447537861230825, n_estimators=133;, score=0.721 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.7003407680324399, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=29, max_samples=0.8936229759407601, min_impurity_decrease=0.4341200586509771, min_samples_leaf=6, min_samples_split=6, min_weight_fraction_leaf=0.20645073275348189, n_estimators=169;, score=0.723 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.7003407680324399, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=29, max_samples=0.8936229759407601, min_impurity_decrease=0.4341200586509771, min_samples_leaf=6, min_samples_split=6, min_weight_fraction_leaf=0.20645073275348189, n_estimators=169;, score=0.721 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.7003407680324399, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=29, max_samples=0.8936229759407601, min_impurity_decrease=0.4341200586509771, min_samples_leaf=6, min_samples_split=6, min_weight_fraction_leaf=0.20645073275348189, n_estimators=169;, score=0.721 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.14513204239088198, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=23, max_samples=0.9353450181048122, min_impurity_decrease=1.4195273943898155, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.3336630839017065, n_estimators=157;, score=0.723 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.14513204239088198, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=23, max_samples=0.9353450181048122, min_impurity_decrease=1.4195273943898155, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.3336630839017065, n_estimators=157;, score=0.721 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.14513204239088198, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=23, max_samples=0.9353450181048122, min_impurity_decrease=1.4195273943898155, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.3336630839017065, n_estimators=157;, score=0.721 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.348446145356976, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=12, max_samples=0.4345234908179826, min_impurity_decrease=0.560904058054699, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.3127272866309391, n_estimators=21;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.348446145356976, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=12, max_samples=0.4345234908179826, min_impurity_decrease=0.560904058054699, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.3127272866309391, n_estimators=21;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.348446145356976, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=12, max_samples=0.4345234908179826, min_impurity_decrease=0.560904058054699, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.3127272866309391, n_estimators=21;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.788750228726168, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=20, max_samples=0.44491916988117586, min_impurity_decrease=0.2946758029059036, min_samples_leaf=5, min_samples_split=7, min_weight_fraction_leaf=0.34737782841436693, n_estimators=17;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.788750228726168, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=20, max_samples=0.44491916988117586, min_impurity_decrease=0.2946758029059036, min_samples_leaf=5, min_samples_split=7, min_weight_fraction_leaf=0.34737782841436693, n_estimators=17;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.788750228726168, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=20, max_samples=0.44491916988117586, min_impurity_decrease=0.2946758029059036, min_samples_leaf=5, min_samples_split=7, min_weight_fraction_leaf=0.34737782841436693, n_estimators=17;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.2263653865282603, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=8, max_samples=0.27876084542280505, min_impurity_decrease=0.41147341661963005, min_samples_leaf=9, min_samples_split=10, min_weight_fraction_leaf=0.30849485869991533, n_estimators=171;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.2263653865282603, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=8, max_samples=0.27876084542280505, min_impurity_decrease=0.41147341661963005, min_samples_leaf=9, min_samples_split=10, min_weight_fraction_leaf=0.30849485869991533, n_estimators=171;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.2263653865282603, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=8, max_samples=0.27876084542280505, min_impurity_decrease=0.41147341661963005, min_samples_leaf=9, min_samples_split=10, min_weight_fraction_leaf=0.30849485869991533, n_estimators=171;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.013713691253708199, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=22, max_samples=0.8197368552299062, min_impurity_decrease=1.9012678251808186, min_samples_leaf=7, min_samples_split=9, min_weight_fraction_leaf=0.06514800739567173, n_estimators=68;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.013713691253708199, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=22, max_samples=0.8197368552299062, min_impurity_decrease=1.9012678251808186, min_samples_leaf=7, min_samples_split=9, min_weight_fraction_leaf=0.06514800739567173, n_estimators=68;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.013713691253708199, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=22, max_samples=0.8197368552299062, min_impurity_decrease=1.9012678251808186, min_samples_leaf=7, min_samples_split=9, min_weight_fraction_leaf=0.06514800739567173, n_estimators=68;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.3844622780592959, criterion=gini, max_depth=50752164, max_features=None, max_leaf_nodes=8, max_samples=0.6260098468164377, min_impurity_decrease=0.08900045210079412, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.21656702950806078, n_estimators=57;, score=0.723 total time=   0.9s
# [CV 2/3] END ccp_alpha=0.3844622780592959, criterion=gini, max_depth=50752164, max_features=None, max_leaf_nodes=8, max_samples=0.6260098468164377, min_impurity_decrease=0.08900045210079412, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.21656702950806078, n_estimators=57;, score=0.721 total time=   2.0s
# [CV 3/3] END ccp_alpha=0.3844622780592959, criterion=gini, max_depth=50752164, max_features=None, max_leaf_nodes=8, max_samples=0.6260098468164377, min_impurity_decrease=0.08900045210079412, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.21656702950806078, n_estimators=57;, score=0.721 total time=   0.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.5657102997099751, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=13, max_samples=0.36505997941513824, min_impurity_decrease=1.0927818442551014, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.14349745626293084, n_estimators=170;, score=0.723 total time=   1.5s
# [CV 2/3] END ccp_alpha=0.5657102997099751, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=13, max_samples=0.36505997941513824, min_impurity_decrease=1.0927818442551014, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.14349745626293084, n_estimators=170;, score=0.721 total time=   1.4s
# [CV 3/3] END ccp_alpha=0.5657102997099751, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=13, max_samples=0.36505997941513824, min_impurity_decrease=1.0927818442551014, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.14349745626293084, n_estimators=170;, score=0.721 total time=   2.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8817019003925176, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=15, max_samples=0.6389428575632456, min_impurity_decrease=1.636381249681446, min_samples_leaf=3, min_samples_split=7, min_weight_fraction_leaf=0.4447740130989416, n_estimators=15;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.8817019003925176, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=15, max_samples=0.6389428575632456, min_impurity_decrease=1.636381249681446, min_samples_leaf=3, min_samples_split=7, min_weight_fraction_leaf=0.4447740130989416, n_estimators=15;, score=0.721 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.8817019003925176, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=15, max_samples=0.6389428575632456, min_impurity_decrease=1.636381249681446, min_samples_leaf=3, min_samples_split=7, min_weight_fraction_leaf=0.4447740130989416, n_estimators=15;, score=0.721 total time=   0.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.45883096342975016, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=29, max_samples=0.45878165952614447, min_impurity_decrease=1.193881007714627, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.4836710120806671, n_estimators=61;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.45883096342975016, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=29, max_samples=0.45878165952614447, min_impurity_decrease=1.193881007714627, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.4836710120806671, n_estimators=61;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.45883096342975016, criterion=entropy, max_depth=2, max_features=log2, max_leaf_nodes=29, max_samples=0.45878165952614447, min_impurity_decrease=1.193881007714627, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.4836710120806671, n_estimators=61;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.218675093598444, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=20, max_samples=0.9381356720917224, min_impurity_decrease=1.542179459357328, min_samples_leaf=10, min_samples_split=9, min_weight_fraction_leaf=0.22003867862722065, n_estimators=54;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.218675093598444, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=20, max_samples=0.9381356720917224, min_impurity_decrease=1.542179459357328, min_samples_leaf=10, min_samples_split=9, min_weight_fraction_leaf=0.22003867862722065, n_estimators=54;, score=0.721 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.218675093598444, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=20, max_samples=0.9381356720917224, min_impurity_decrease=1.542179459357328, min_samples_leaf=10, min_samples_split=9, min_weight_fraction_leaf=0.22003867862722065, n_estimators=54;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.21250207529853488, criterion=log_loss, max_depth=660195187, max_features=sqrt, max_leaf_nodes=28, max_samples=0.5117871882826399, min_impurity_decrease=0.5989394514347616, min_samples_leaf=3, min_samples_split=4, min_weight_fraction_leaf=0.4535648600899346, n_estimators=79;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.21250207529853488, criterion=log_loss, max_depth=660195187, max_features=sqrt, max_leaf_nodes=28, max_samples=0.5117871882826399, min_impurity_decrease=0.5989394514347616, min_samples_leaf=3, min_samples_split=4, min_weight_fraction_leaf=0.4535648600899346, n_estimators=79;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.21250207529853488, criterion=log_loss, max_depth=660195187, max_features=sqrt, max_leaf_nodes=28, max_samples=0.5117871882826399, min_impurity_decrease=0.5989394514347616, min_samples_leaf=3, min_samples_split=4, min_weight_fraction_leaf=0.4535648600899346, n_estimators=79;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9318092319710098, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=26, max_samples=0.2611025025117464, min_impurity_decrease=0.2857230093502435, min_samples_leaf=1, min_samples_split=9, min_weight_fraction_leaf=0.03960323562734281, n_estimators=122;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.9318092319710098, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=26, max_samples=0.2611025025117464, min_impurity_decrease=0.2857230093502435, min_samples_leaf=1, min_samples_split=9, min_weight_fraction_leaf=0.03960323562734281, n_estimators=122;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.9318092319710098, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=26, max_samples=0.2611025025117464, min_impurity_decrease=0.2857230093502435, min_samples_leaf=1, min_samples_split=9, min_weight_fraction_leaf=0.03960323562734281, n_estimators=122;, score=0.721 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9451229709917747, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=13, max_samples=0.30728523735110447, min_impurity_decrease=0.4489480473883344, min_samples_leaf=3, min_samples_split=7, min_weight_fraction_leaf=0.05543940497871076, n_estimators=49;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.9451229709917747, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=13, max_samples=0.30728523735110447, min_impurity_decrease=0.4489480473883344, min_samples_leaf=3, min_samples_split=7, min_weight_fraction_leaf=0.05543940497871076, n_estimators=49;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.9451229709917747, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=13, max_samples=0.30728523735110447, min_impurity_decrease=0.4489480473883344, min_samples_leaf=3, min_samples_split=7, min_weight_fraction_leaf=0.05543940497871076, n_estimators=49;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8502744117517135, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=22, max_samples=0.46950280170697734, min_impurity_decrease=0.8575146446279609, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.46753588186357625, n_estimators=151;, score=0.723 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.8502744117517135, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=22, max_samples=0.46950280170697734, min_impurity_decrease=0.8575146446279609, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.46753588186357625, n_estimators=151;, score=0.721 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.8502744117517135, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=22, max_samples=0.46950280170697734, min_impurity_decrease=0.8575146446279609, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.46753588186357625, n_estimators=151;, score=0.721 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.33230618802851825, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=22, max_samples=0.39331878675742443, min_impurity_decrease=1.6360494236485652, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.15849322343374947, n_estimators=11;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.33230618802851825, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=22, max_samples=0.39331878675742443, min_impurity_decrease=1.6360494236485652, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.15849322343374947, n_estimators=11;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.33230618802851825, criterion=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=22, max_samples=0.39331878675742443, min_impurity_decrease=1.6360494236485652, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.15849322343374947, n_estimators=11;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.011441283418111127, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=12, max_samples=0.3304848628800031, min_impurity_decrease=1.808316466739585, min_samples_leaf=9, min_samples_split=9, min_weight_fraction_leaf=0.180746297988317, n_estimators=193;, score=0.723 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.011441283418111127, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=12, max_samples=0.3304848628800031, min_impurity_decrease=1.808316466739585, min_samples_leaf=9, min_samples_split=9, min_weight_fraction_leaf=0.180746297988317, n_estimators=193;, score=0.721 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.011441283418111127, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=12, max_samples=0.3304848628800031, min_impurity_decrease=1.808316466739585, min_samples_leaf=9, min_samples_split=9, min_weight_fraction_leaf=0.180746297988317, n_estimators=193;, score=0.721 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.06871614419035645, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=10, max_samples=0.6828836715454085, min_impurity_decrease=0.5081313757132632, min_samples_leaf=2, min_samples_split=6, min_weight_fraction_leaf=0.15499741509158063, n_estimators=18;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.06871614419035645, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=10, max_samples=0.6828836715454085, min_impurity_decrease=0.5081313757132632, min_samples_leaf=2, min_samples_split=6, min_weight_fraction_leaf=0.15499741509158063, n_estimators=18;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.06871614419035645, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=10, max_samples=0.6828836715454085, min_impurity_decrease=0.5081313757132632, min_samples_leaf=2, min_samples_split=6, min_weight_fraction_leaf=0.15499741509158063, n_estimators=18;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9284905613988049, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=13, max_samples=0.8826361430067904, min_impurity_decrease=1.4138695778109136, min_samples_leaf=5, min_samples_split=6, min_weight_fraction_leaf=0.13867023024948463, n_estimators=31;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.9284905613988049, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=13, max_samples=0.8826361430067904, min_impurity_decrease=1.4138695778109136, min_samples_leaf=5, min_samples_split=6, min_weight_fraction_leaf=0.13867023024948463, n_estimators=31;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.9284905613988049, criterion=entropy, max_depth=2, max_features=sqrt, max_leaf_nodes=13, max_samples=0.8826361430067904, min_impurity_decrease=1.4138695778109136, min_samples_leaf=5, min_samples_split=6, min_weight_fraction_leaf=0.13867023024948463, n_estimators=31;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.5555356825255471, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=25, max_samples=0.8556328033133742, min_impurity_decrease=1.144808684825412, min_samples_leaf=1, min_samples_split=7, min_weight_fraction_leaf=0.26622429781419027, n_estimators=47;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.5555356825255471, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=25, max_samples=0.8556328033133742, min_impurity_decrease=1.144808684825412, min_samples_leaf=1, min_samples_split=7, min_weight_fraction_leaf=0.26622429781419027, n_estimators=47;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.5555356825255471, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=25, max_samples=0.8556328033133742, min_impurity_decrease=1.144808684825412, min_samples_leaf=1, min_samples_split=7, min_weight_fraction_leaf=0.26622429781419027, n_estimators=47;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=5, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=10;, score=0.738 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=5, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=10;, score=0.750 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=5, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=10;, score=0.701 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=0.2, min_impurity_decrease=2.0, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.723 total time=   0.9s
# [CV 2/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=0.2, min_impurity_decrease=2.0, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.721 total time=   1.0s
# [CV 3/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=0.2, min_impurity_decrease=2.0, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.721 total time=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8325203102339817, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=18, max_samples=0.37598119611778597, min_impurity_decrease=0.038351430089213163, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.4801247053442311, n_estimators=22;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.8325203102339817, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=18, max_samples=0.37598119611778597, min_impurity_decrease=0.038351430089213163, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.4801247053442311, n_estimators=22;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.8325203102339817, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=18, max_samples=0.37598119611778597, min_impurity_decrease=0.038351430089213163, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.4801247053442311, n_estimators=22;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.3224302857822276, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=23, max_samples=0.9908214264595123, min_impurity_decrease=0.12879039337958312, min_samples_leaf=4, min_samples_split=2, min_weight_fraction_leaf=0.49994362182032376, n_estimators=134;, score=0.723 total time=   1.9s
# [CV 2/3] END ccp_alpha=0.3224302857822276, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=23, max_samples=0.9908214264595123, min_impurity_decrease=0.12879039337958312, min_samples_leaf=4, min_samples_split=2, min_weight_fraction_leaf=0.49994362182032376, n_estimators=134;, score=0.721 total time=   1.8s
# [CV 3/3] END ccp_alpha=0.3224302857822276, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=23, max_samples=0.9908214264595123, min_impurity_decrease=0.12879039337958312, min_samples_leaf=4, min_samples_split=2, min_weight_fraction_leaf=0.49994362182032376, n_estimators=134;, score=0.721 total time=   2.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.24271444592964658, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=29, max_samples=0.8839590581874361, min_impurity_decrease=1.8972257714950578, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.48870273462737757, n_estimators=146;, score=0.723 total time=   2.0s
# [CV 2/3] END ccp_alpha=0.24271444592964658, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=29, max_samples=0.8839590581874361, min_impurity_decrease=1.8972257714950578, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.48870273462737757, n_estimators=146;, score=0.721 total time=   2.0s
# [CV 3/3] END ccp_alpha=0.24271444592964658, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=29, max_samples=0.8839590581874361, min_impurity_decrease=1.8972257714950578, min_samples_leaf=5, min_samples_split=2, min_weight_fraction_leaf=0.48870273462737757, n_estimators=146;, score=0.721 total time=   1.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.00874663455298619, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=29, max_samples=0.6909959042034814, min_impurity_decrease=0.9134373722386948, min_samples_leaf=4, min_samples_split=9, min_weight_fraction_leaf=0.0028681270567350596, n_estimators=54;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.00874663455298619, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=29, max_samples=0.6909959042034814, min_impurity_decrease=0.9134373722386948, min_samples_leaf=4, min_samples_split=9, min_weight_fraction_leaf=0.0028681270567350596, n_estimators=54;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.00874663455298619, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=29, max_samples=0.6909959042034814, min_impurity_decrease=0.9134373722386948, min_samples_leaf=4, min_samples_split=9, min_weight_fraction_leaf=0.0028681270567350596, n_estimators=54;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.7338834533825672, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=29, max_samples=0.6750886206659037, min_impurity_decrease=1.5471899620651495, min_samples_leaf=4, min_samples_split=10, min_weight_fraction_leaf=0.00036681565820267947, n_estimators=135;, score=0.723 total time=   2.1s
# [CV 2/3] END ccp_alpha=0.7338834533825672, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=29, max_samples=0.6750886206659037, min_impurity_decrease=1.5471899620651495, min_samples_leaf=4, min_samples_split=10, min_weight_fraction_leaf=0.00036681565820267947, n_estimators=135;, score=0.721 total time=   2.1s
# [CV 3/3] END ccp_alpha=0.7338834533825672, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=29, max_samples=0.6750886206659037, min_impurity_decrease=1.5471899620651495, min_samples_leaf=4, min_samples_split=10, min_weight_fraction_leaf=0.00036681565820267947, n_estimators=135;, score=0.721 total time=   2.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.09200382428732236, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=29, max_samples=0.7738410405278966, min_impurity_decrease=1.0117473405447657, min_samples_leaf=9, min_samples_split=10, min_weight_fraction_leaf=0.49701844307836657, n_estimators=92;, score=0.723 total time=   1.1s
# [CV 2/3] END ccp_alpha=0.09200382428732236, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=29, max_samples=0.7738410405278966, min_impurity_decrease=1.0117473405447657, min_samples_leaf=9, min_samples_split=10, min_weight_fraction_leaf=0.49701844307836657, n_estimators=92;, score=0.721 total time=   1.2s
# [CV 3/3] END ccp_alpha=0.09200382428732236, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=29, max_samples=0.7738410405278966, min_impurity_decrease=1.0117473405447657, min_samples_leaf=9, min_samples_split=10, min_weight_fraction_leaf=0.49701844307836657, n_estimators=92;, score=0.721 total time=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.25142441134191024, criterion=entropy, max_depth=1502024127, max_features=None, max_leaf_nodes=10, max_samples=0.4734300421230584, min_impurity_decrease=1.8977719687125616, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.25106680385012164, n_estimators=12;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.25142441134191024, criterion=entropy, max_depth=1502024127, max_features=None, max_leaf_nodes=10, max_samples=0.4734300421230584, min_impurity_decrease=1.8977719687125616, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.25106680385012164, n_estimators=12;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.25142441134191024, criterion=entropy, max_depth=1502024127, max_features=None, max_leaf_nodes=10, max_samples=0.4734300421230584, min_impurity_decrease=1.8977719687125616, min_samples_leaf=2, min_samples_split=10, min_weight_fraction_leaf=0.25106680385012164, n_estimators=12;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9158924512957696, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=8, max_samples=0.30698072739311477, min_impurity_decrease=0.14957034055607268, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.001278671407559995, n_estimators=70;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.9158924512957696, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=8, max_samples=0.30698072739311477, min_impurity_decrease=0.14957034055607268, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.001278671407559995, n_estimators=70;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.9158924512957696, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=8, max_samples=0.30698072739311477, min_impurity_decrease=0.14957034055607268, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.001278671407559995, n_estimators=70;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.011587087010988208, criterion=gini, max_depth=1369877783, max_features=log2, max_leaf_nodes=29, max_samples=0.3357618430773365, min_impurity_decrease=0.4446150687010041, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.4988956808069557, n_estimators=150;, score=0.723 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.011587087010988208, criterion=gini, max_depth=1369877783, max_features=log2, max_leaf_nodes=29, max_samples=0.3357618430773365, min_impurity_decrease=0.4446150687010041, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.4988956808069557, n_estimators=150;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.011587087010988208, criterion=gini, max_depth=1369877783, max_features=log2, max_leaf_nodes=29, max_samples=0.3357618430773365, min_impurity_decrease=0.4446150687010041, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.4988956808069557, n_estimators=150;, score=0.721 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=959612603, max_features=None, max_leaf_nodes=5, max_samples=0.2, min_impurity_decrease=2.0, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.5, n_estimators=200;, score=0.723 total time=   0.9s
# [CV 2/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=959612603, max_features=None, max_leaf_nodes=5, max_samples=0.2, min_impurity_decrease=2.0, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.5, n_estimators=200;, score=0.721 total time=   0.8s
# [CV 3/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=959612603, max_features=None, max_leaf_nodes=5, max_samples=0.2, min_impurity_decrease=2.0, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.5, n_estimators=200;, score=0.721 total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.012932322530686772, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=5, max_samples=0.9618358847500765, min_impurity_decrease=0.901553480660052, min_samples_leaf=4, min_samples_split=2, min_weight_fraction_leaf=0.33125709949176785, n_estimators=29;, score=0.723 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.012932322530686772, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=5, max_samples=0.9618358847500765, min_impurity_decrease=0.901553480660052, min_samples_leaf=4, min_samples_split=2, min_weight_fraction_leaf=0.33125709949176785, n_estimators=29;, score=0.721 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.012932322530686772, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=5, max_samples=0.9618358847500765, min_impurity_decrease=0.901553480660052, min_samples_leaf=4, min_samples_split=2, min_weight_fraction_leaf=0.33125709949176785, n_estimators=29;, score=0.721 total time=   0.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.05924258862421973, criterion=gini, max_depth=1594582041, max_features=sqrt, max_leaf_nodes=11, max_samples=0.8482405951799545, min_impurity_decrease=1.6178756170711694, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.012507915931836092, n_estimators=87;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.05924258862421973, criterion=gini, max_depth=1594582041, max_features=sqrt, max_leaf_nodes=11, max_samples=0.8482405951799545, min_impurity_decrease=1.6178756170711694, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.012507915931836092, n_estimators=87;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.05924258862421973, criterion=gini, max_depth=1594582041, max_features=sqrt, max_leaf_nodes=11, max_samples=0.8482405951799545, min_impurity_decrease=1.6178756170711694, min_samples_leaf=10, min_samples_split=2, min_weight_fraction_leaf=0.012507915931836092, n_estimators=87;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=0.2, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=10;, score=0.770 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=0.2, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=10;, score=0.745 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=0.2, min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=10, min_weight_fraction_leaf=0.0, n_estimators=10;, score=0.675 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# ...
# [CV 2/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.7s
# [CV 3/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   7.1s
# [CV 2/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.0s
# [CV 3/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   7.3s
# [CV 2/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.1s
# [CV 3/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   6.8s
# [CV 2/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.5s
# [CV 3/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   7.0s
# [CV 2/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   6.9s
# [CV 3/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.721 total time=   6.1s
# [CV 2/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   6.2s
# [CV 3/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.780 total time=   5.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.721 total time=   6.2s
# [CV 2/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   6.2s
# [CV 3/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.780 total time=   5.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   6.8s
# [CV 2/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.1s
# [CV 3/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   7.2s
# [CV 2/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   8.0s
# [CV 3/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   7.2s
# [CV 2/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.0s
# [CV 3/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   6.5s
# [CV 2/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   6.6s
# [CV 3/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.721 total time=   5.4s
# [CV 2/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   5.3s
# [CV 3/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.780 total time=   6.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   7.4s
# [CV 2/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.1s
# [CV 3/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=5, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   7.1s
# [CV 2/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.1s
# [CV 3/3] END ccp_alpha=0.0, criterion=log_loss, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.721 total time=   6.7s
# [CV 2/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   6.0s
# [CV 3/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.780 total time=   6.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.721 total time=   6.3s
# [CV 2/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   6.7s
# [CV 3/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.780 total time=   6.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   7.4s
# [CV 2/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.5s
# [CV 3/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.718 total time=   8.5s
# [CV 2/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   7.5s
# [CV 3/3] END ccp_alpha=0.0, criterion=entropy, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=3, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   9.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.721 total time=   7.2s
# [CV 2/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.791 total time=   6.8s
# [CV 3/3] END ccp_alpha=0.0, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=30, max_samples=1.0, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.0, n_estimators=200;, score=0.780 total time=   7.8s

# %%
print('Best score using 3-fold cross validation:', round(opt.best_score_,5))
# Out:
# Best score using 3-fold cross validation: 0.87628

# %%
print('Best parameters using 3-fold cross validation::', opt.best_params_)
# Out:
# Best parameters using 3-fold cross validation:: OrderedDict([('ccp_alpha', 0.0), ('criterion', 'entropy'), ('max_depth', 1781108027), ('max_features', None), ('max_leaf_nodes', 30), ('max_samples', 1.0), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 3), ('min_weight_fraction_leaf', 0.0), ('n_estimators', 200)])

# %% [markdown]
# ## Trying Grid search CV

# %%
parameters = {'n_estimators': [50,150,200],'criterion' : ['gini', 'entropy', 'log_loss'], 'max_depth': [2,8,15,22,None],
              'max_features':[None, 'sqrt','log2'], 'class_weight': [{0:1, 1:1.5}], 'ccp_alpha':[0,0.3], 'max_samples': [0.45, 0.8,1], 
              'max_leaf_nodes': [None, 2, 6, 17]} 
fbeta_scorer = make_scorer(fbeta_score, beta = 1.4)

# %%
opt_gs = GridSearchCV(RandomForestClassifier(random_state = 5000), parameters, scoring = fbeta_scorer, verbose = 5, cv = 3)

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    opt_gs.fit(X_train_gray_sc, y_train_final)
# Out:
# Fitting 3 folds for each of 3240 candidates, totalling 9720 fits
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=50;, score=0.724 total time=   0.9s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=50;, score=0.763 total time=   0.9s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=50;, score=0.771 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=150;, score=0.739 total time=   2.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=150;, score=0.777 total time=   2.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=150;, score=0.774 total time=   2.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=200;, score=0.739 total time=   4.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=200;, score=0.788 total time=   4.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=200;, score=0.782 total time=   4.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=50;, score=0.683 total time=   1.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=50;, score=0.765 total time=   1.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=50;, score=0.747 total time=   1.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=150;, score=0.716 total time=   4.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=150;, score=0.781 total time=   4.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=150;, score=0.774 total time=   3.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=200;, score=0.713 total time=   4.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=200;, score=0.780 total time=   6.4s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=200;, score=0.789 total time=   4.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=200;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=200;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=200;, score=0.721 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.712 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.727 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.725 total time=   1.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.717 total time=   2.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.728 total time=   2.4s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.741 total time=   2.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.726 total time=   3.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.737 total time=   3.4s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.750 total time=   4.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.709 total time=   1.4s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.694 total time=   1.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.731 total time=   1.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=150;, score=0.705 total time=   4.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=150;, score=0.725 total time=   4.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=150;, score=0.735 total time=   4.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=200;, score=0.705 total time=   7.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=200;, score=0.732 total time=  10.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=200;, score=0.724 total time=   8.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=150;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=150;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=150;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=200;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=200;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=200;, score=0.721 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=50;, score=0.724 total time=   1.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=50;, score=0.763 total time=   1.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=50;, score=0.771 total time=   1.4s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=150;, score=0.739 total time=   4.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=150;, score=0.777 total time=   3.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=150;, score=0.774 total time=   3.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=200;, score=0.739 total time=   4.9s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=200;, score=0.788 total time=   4.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=200;, score=0.782 total time=   5.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=50;, score=0.683 total time=   1.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=50;, score=0.765 total time=   1.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=50;, score=0.747 total time=   1.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=150;, score=0.716 total time=   5.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=150;, score=0.781 total time=   5.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=150;, score=0.774 total time=   5.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=200;, score=0.713 total time=   6.4s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=200;, score=0.780 total time=   6.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=200;, score=0.789 total time=   6.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=200;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=200;, score=0.721 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=50;, score=0.724 total time=   1.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=50;, score=0.763 total time=   1.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=50;, score=0.771 total time=   1.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=150;, score=0.739 total time=   3.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=150;, score=0.777 total time=   3.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=150;, score=0.774 total time=   3.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=200;, score=0.739 total time=   4.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=200;, score=0.788 total time=   4.8s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=200;, score=0.782 total time=   4.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=50;, score=0.683 total time=   2.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=50;, score=0.765 total time=   1.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=50;, score=0.747 total time=   1.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=150;, score=0.716 total time=   5.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=150;, score=0.781 total time=   5.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=150;, score=0.774 total time=   4.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=200;, score=0.713 total time=   6.9s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=200;, score=0.780 total time=   7.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=200;, score=0.789 total time=   6.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=200;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=200;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=200;, score=0.721 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=50;, score=0.782 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=50;, score=0.775 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=50;, score=0.748 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=150;, score=0.761 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=150;, score=0.769 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=150;, score=0.762 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=200;, score=0.757 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=200;, score=0.774 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=200;, score=0.760 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=50;, score=0.774 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=50;, score=0.789 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=50;, score=0.754 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=150;, score=0.772 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=150;, score=0.789 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=150;, score=0.766 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=200;, score=0.755 total time=   1.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=200;, score=0.780 total time=   1.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=200;, score=0.771 total time=   1.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=150;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=200;, score=0.721 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.729 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.729 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.730 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.725 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.725 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.721 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.725 total time=   1.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.725 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.721 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.731 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.733 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.730 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=150;, score=0.730 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=150;, score=0.724 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=150;, score=0.722 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=200;, score=0.726 total time=   1.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=200;, score=0.722 total time=   0.9s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=200;, score=0.722 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=150;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=200;, score=0.721 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=50;, score=0.782 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=50;, score=0.775 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=50;, score=0.748 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=150;, score=0.761 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=150;, score=0.769 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=150;, score=0.762 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=200;, score=0.757 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=200;, score=0.774 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=200;, score=0.760 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=50;, score=0.774 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=50;, score=0.789 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=50;, score=0.754 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=150;, score=0.772 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=150;, score=0.789 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=150;, score=0.766 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=200;, score=0.755 total time=   0.9s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=200;, score=0.780 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=200;, score=0.771 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=200;, score=0.721 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=50;, score=0.782 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=50;, score=0.775 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=50;, score=0.748 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=150;, score=0.761 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=150;, score=0.769 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=150;, score=0.762 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=200;, score=0.757 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=200;, score=0.774 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=200;, score=0.760 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=50;, score=0.774 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=50;, score=0.789 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=50;, score=0.754 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=150;, score=0.772 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=150;, score=0.789 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=150;, score=0.766 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=200;, score=0.755 total time=   1.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=200;, score=0.780 total time=   1.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=200;, score=0.771 total time=   1.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=200;, score=0.721 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=50;, score=0.734 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=50;, score=0.766 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=50;, score=0.757 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=150;, score=0.752 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=150;, score=0.771 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=150;, score=0.752 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=200;, score=0.762 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=200;, score=0.765 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=200;, score=0.753 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=50;, score=0.761 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=50;, score=0.761 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=50;, score=0.735 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=150;, score=0.770 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=150;, score=0.766 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=150;, score=0.745 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=200;, score=0.762 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=200;, score=0.771 total time=   0.9s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=200;, score=0.748 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=200;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=200;, score=0.721 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.724 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.726 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.729 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.725 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.721 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.721 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.725 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.721 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.721 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.728 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.729 total time=   0.1s
# ...
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=50;, score=0.721 total time=   0.0s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.723 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=150;, score=0.721 total time=   0.2s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.723 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.721 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=200;, score=0.721 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=50;, score=0.721 total time=   0.0s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=150;, score=0.723 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=150;, score=0.721 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=150;, score=0.721 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=200;, score=0.723 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=200;, score=0.721 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=200;, score=0.721 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=150;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=200;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=200;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=200;, score=0.721 total time=   0.1s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=50;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=50;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=50;, score=0.721 total time=   0.1s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=150;, score=0.723 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=150;, score=0.721 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=150;, score=0.721 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=200;, score=0.723 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=200;, score=0.721 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=200;, score=0.721 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=50;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=50;, score=0.721 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=50;, score=0.721 total time=   0.1s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=150;, score=0.723 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=150;, score=0.721 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=150;, score=0.721 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=200;, score=0.723 total time=   0.8s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=200;, score=0.721 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=200;, score=0.721 total time=   0.8s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=150;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=200;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=200;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=200;, score=0.721 total time=   0.2s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=50;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=50;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=50;, score=0.721 total time=   0.2s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=150;, score=0.723 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=150;, score=0.721 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=150;, score=0.721 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=200;, score=0.723 total time=   0.8s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=200;, score=0.721 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=200;, score=0.721 total time=   0.7s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=50;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=50;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=50;, score=0.721 total time=   0.2s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=150;, score=0.723 total time=   0.8s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=150;, score=0.721 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=150;, score=0.721 total time=   0.8s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=200;, score=0.723 total time=   1.2s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=200;, score=0.721 total time=   1.1s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=200;, score=0.721 total time=   1.0s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=200;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=200;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=200;, score=0.721 total time=   0.1s

# %%
print('Best score using 3-fold cross validation:', round(opt_gs.best_score_,5))
# Out:
# Best score using 3-fold cross validation: 0.87961

# %%
print('Best parameters using 3-fold cross validation:', opt_gs.best_params_)
# Out:
# Best parameters using 3-fold cross validation: {'ccp_alpha': 0, 'class_weight': {0: 1, 1: 1.5}, 'criterion': 'entropy', 'max_depth': 15, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 0.8, 'n_estimators': 200}

# %%
## Grid searching beyond 200 for parameter 'n_estimators' as it has taken a border grid

parameters = {'n_estimators': [220, 240],'criterion' : ['gini', 'entropy', 'log_loss'], 'max_depth': [2,8,15,22,None],
              'max_features':[None, 'sqrt','log2'], 'class_weight': [{0:1, 1:1.5}], 'ccp_alpha':[0,0.3], 'max_samples': [0.45, 0.8,1], 
              'max_leaf_nodes': [None, 2, 6, 17]} 
fbeta_scorer = make_scorer(fbeta_score, beta = 1.4)

# %%
opt_gs2 = GridSearchCV(RandomForestClassifier(random_state = 5000), parameters, scoring = fbeta_scorer, verbose = 5, cv = 3)

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    opt_gs2.fit(X_train_gray_sc, y_train_final)
# Out:
# Fitting 3 folds for each of 2160 candidates, totalling 6480 fits
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.736 total time=   3.4s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.779 total time=   3.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.780 total time=   4.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.726 total time=   4.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.775 total time=   4.9s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.786 total time=   5.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.718 total time=   5.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.778 total time=   5.4s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.783 total time=   5.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.715 total time=   5.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.772 total time=   5.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.791 total time=   5.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.720 total time=   3.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.738 total time=   3.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.749 total time=   3.4s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.718 total time=   3.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.738 total time=   3.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.748 total time=   3.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.711 total time=   5.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.734 total time=   5.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.728 total time=   5.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.711 total time=   5.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.728 total time=   5.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.735 total time=   5.4s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.736 total time=   3.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.779 total time=   3.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.780 total time=   3.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.726 total time=   3.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.775 total time=   4.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.786 total time=   3.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.718 total time=   5.4s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.778 total time=   5.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.783 total time=   6.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.715 total time=   6.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.772 total time=   5.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.791 total time=   6.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.736 total time=   4.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.779 total time=   3.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.780 total time=   3.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.726 total time=   4.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.775 total time=   4.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.786 total time=   3.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.718 total time=   5.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.778 total time=   6.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.783 total time=   6.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.715 total time=   6.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.772 total time=   5.9s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.791 total time=   5.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=None, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.763 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.780 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.765 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.769 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.771 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.764 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.758 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.786 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.768 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.755 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.782 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.770 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.728 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.725 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.721 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.725 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.725 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.721 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.725 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.725 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.721 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.725 total time=   1.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.725 total time=   1.0s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.721 total time=   1.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.763 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.780 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.765 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.769 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.771 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.764 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.758 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.786 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.768 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.755 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.782 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.770 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.763 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.780 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.765 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.769 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.771 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.764 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.758 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.786 total time=   0.9s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.768 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.755 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.782 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.770 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.761 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.762 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.748 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.763 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.763 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.748 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.770 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.763 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.746 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.768 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.762 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.742 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.725 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.721 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.721 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.725 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.721 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.721 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.725 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.721 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.721 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.725 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.721 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.721 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.761 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.762 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.748 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.763 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.763 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.748 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.770 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.763 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.746 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.768 total time=   0.9s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.762 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.742 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.761 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.762 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.748 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.763 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.763 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.748 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.770 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.763 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.746 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.768 total time=   0.9s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.762 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.742 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=2, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.839 total time=  10.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.844 total time=  10.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.792 total time=  10.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.843 total time=  11.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.833 total time=  11.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.788 total time=  10.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.856 total time=  17.3s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.847 total time=  17.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.835 total time=  17.9s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.856 total time=  16.9s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.849 total time=  17.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.833 total time=  17.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.720 total time=   3.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.738 total time=   3.7s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.749 total time=   3.4s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.718 total time=   4.0s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.738 total time=   4.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.748 total time=   4.0s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.711 total time=   5.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.734 total time=   5.3s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.728 total time=   5.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.711 total time=   5.8s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.728 total time=   5.9s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.735 total time=   5.7s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, class_weight={0: 1, 1: 1.5}, criterion=gini, max_depth=8, max_features=None, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.729 total time=   7.0s
# ...
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.721 total time=   3.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=sqrt, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.721 total time=   3.4s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=sqrt, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.723 total time=   1.6s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.721 total time=   1.7s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=220;, score=0.721 total time=   1.8s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.723 total time=   2.0s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.721 total time=   1.9s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.45, n_estimators=240;, score=0.721 total time=   2.1s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.723 total time=   2.7s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.721 total time=   2.7s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=220;, score=0.721 total time=   2.7s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.723 total time=   3.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.721 total time=   3.1s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=0.8, n_estimators=240;, score=0.721 total time=   2.9s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=None, max_samples=1, n_estimators=240;, score=0.000 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.723 total time=   0.8s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.721 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=220;, score=0.721 total time=   0.7s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.723 total time=   0.9s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.721 total time=   0.8s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.45, n_estimators=240;, score=0.721 total time=   0.9s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.723 total time=   1.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.721 total time=   1.0s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=220;, score=0.721 total time=   1.1s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.723 total time=   1.3s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.721 total time=   1.1s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=0.8, n_estimators=240;, score=0.721 total time=   1.0s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=2, max_samples=1, n_estimators=240;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.723 total time=   1.2s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.721 total time=   1.1s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=220;, score=0.721 total time=   1.2s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.723 total time=   1.6s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.721 total time=   1.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.45, n_estimators=240;, score=0.721 total time=   1.3s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.723 total time=   1.7s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.721 total time=   1.8s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=220;, score=0.721 total time=   1.6s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.723 total time=   1.9s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.721 total time=   1.8s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=0.8, n_estimators=240;, score=0.721 total time=   1.9s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=220;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=6, max_samples=1, n_estimators=240;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.723 total time=   1.6s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.721 total time=   1.5s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=220;, score=0.721 total time=   1.5s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.723 total time=   1.7s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.721 total time=   1.8s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.45, n_estimators=240;, score=0.721 total time=   1.8s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.723 total time=   2.1s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.721 total time=   2.2s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=220;, score=0.721 total time=   2.3s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.723 total time=   2.7s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.721 total time=   2.5s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=0.8, n_estimators=240;, score=0.721 total time=   2.5s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=220;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, class_weight={0: 1, 1: 1.5}, criterion=log_loss, max_depth=None, max_features=log2, max_leaf_nodes=17, max_samples=1, n_estimators=240;, score=0.000 total time=   0.5s

# %%
print('Best score using 3-fold cross validation:', round(opt_gs2.best_score_,5))
# Out:
# Best score using 3-fold cross validation: 0.88069

# %%
print('Best parameters using 3-fold cross validation:', opt_gs2.best_params_)
# Out:
# Best parameters using 3-fold cross validation: {'ccp_alpha': 0, 'class_weight': {0: 1, 1: 1.5}, 'criterion': 'entropy', 'max_depth': 15, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 0.8, 'n_estimators': 220}

# %% [markdown]
# But the score reduced when we extended the search space for parameters which had edge cases selected as best values.

# %% [markdown]
# ### From the cross-validation scores, best model found by the first Grid Search.

# %%
clf = RandomForestClassifier(random_state=5000, **opt_gs.best_params_)
clf
# Out:
# RandomForestClassifier(ccp_alpha=0, class_weight={0: 1, 1: 1.5},
#                        criterion='entropy', max_depth=15, max_features='log2',
#                        max_samples=0.8, n_estimators=200, random_state=5000)

# %%
clf.fit(X_train_gray_sc, y_train_final)
pred_gray_val = clf.predict(X_test_gray_sc)
calculate_metrics(pred_gray_val, y_test)
# Out:
# Accuracy in detecting Accident class: 0.94
#
# ------------------------------------------------------------------------------------------
#
# +-----------+-----------------------+-------------------+
# | Metric    |   Non-Accident images |   Accident images |
# +===========+=======================+===================+
# | Precision |                  0.9  |              1    |
# +-----------+-----------------------+-------------------+
# | Recall    |                  1    |              0.87 |
# +-----------+-----------------------+-------------------+
# | f1-score  |                  0.95 |              0.93 |
# +-----------+-----------------------+-------------------+
#
# ------------------------------------------------------------------------------------------
#
# Sensitivity/ ability to correctly classifiy to Accident class is: 0.87
# Specificity/ ability to correctly classifiy to Non-Accident class is: 1.0
#
# ------------------------------------------------------------------------------------------
#
# Fbeta score with beta = 1.5 is: 0.91
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
#
# AUC score is: 0.94

# %% [markdown]
# So, the best we could do using **Random Forest** is a test fbeta score (beta = 1.4) of 0.91, with the parameters:
#
# - random_state = 5000
# - 'ccp_alpha': 0
# - 'class_weight': {0: 1, 1: 1.5}
# - 'criterion': 'entropy'
# - 'max_depth': 15
# - 'max_features': 'log2'
# - 'max_leaf_nodes': None
# - 'max_samples': 0.8
# - 'n_estimators': 200
