# %% [markdown]
# # 0. Imports

# %%
# for data handling and manipulation:
import pandas as pd
import numpy as np

# for os handling
import os

# for pre-processing
from sklearn.preprocessing import StandardScaler

# import the classifiers to fit:
from sklearn.ensemble import GradientBoostingClassifier

# import metrics
from sklearn.metrics import fbeta_score, classification_report, accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, roc_auc_score, auc, ConfusionMatrixDisplay, make_scorer

# for tabulating results
from tabulate import tabulate

# for visualizations
import seaborn as sns
import matplotlib.pyplot as plt

# for handling warnings
import warnings

# for hyper-parameter tuning
from skopt import BayesSearchCV
from skopt.space import Integer, Real
from sklearn.model_selection import GridSearchCV

# %%
# Reading the train, test and validation data into this notebook 

X_train_gray = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\X_train_gray.csv').drop(columns = ['Unnamed: 0'], axis = 1)
X_train_gray = X_train_gray.to_numpy()

y_train = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\y_train.csv').drop(columns = ['Unnamed: 0'], axis = 1)
y_train = y_train.to_numpy(dtype = 'int64').flatten()

X_val_gray = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\X_val_gray.csv').drop(columns = ['Unnamed: 0'], axis = 1)
X_val_gray = X_val_gray.to_numpy()

y_val = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\y_val.csv').drop(columns = ['Unnamed: 0'], axis = 1)
y_val = y_val.to_numpy(dtype = 'int64').flatten()

X_test_gray = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\X_test_gray.csv').drop(columns = ['Unnamed: 0'], axis = 1)
X_test_gray = X_test_gray.to_numpy()

y_test = pd.read_csv(r'D:\CMI LOCAL\PROJECTS\ML Project\Prepared data\y_test.csv').drop(columns = ['Unnamed: 0'], axis = 1)
y_test = y_test.to_numpy(dtype = 'int64').flatten()

# %%
X_train_gray.shape, y_train.shape, X_val_gray.shape, y_val.shape, X_test_gray.shape, y_test.shape
# Out:
# ((791, 98), (791,), (98, 98), (98,), (100, 98), (100,))

# %%
X_final_train_gray = np.concatenate((X_train_gray, X_val_gray), axis = 0)
y_train_final = np.concatenate((y_train, y_val), axis = 0)

# %% [markdown]
# ## Function to calculate metrics

# %%
def calculate_metrics(y_pred, y_true, normalize = False):
    
    with warnings.catch_warnings():
        
        warnings.filterwarnings('ignore')
        # calculate accuracy:
        temp = round(accuracy_score(y_true, y_pred),2)
        print('Accuracy in detecting Accident class: {}'.format(temp))
        print('\n------------------------------------------------------------------------------------------\n')
        
        my_data = []
        cr = classification_report(y_true, y_pred, output_dict = True)

        # calculate precision:
        my_data.append(['Precision',round(cr['0']['precision'],2), round(cr['1']['precision'],2)])

        # calculate recall:
        my_data.append(['Recall',round(cr['0']['recall'],2), round(cr['1']['recall'],2)])

        # f1-score:
        my_data.append(['f1-score',round(cr['0']['f1-score'],2), round(cr['1']['f1-score'],2)])

        head = ['Metric','Non-Accident images','Accident images']

        print(tabulate(my_data, headers = head, tablefmt = 'grid'))
        print('\n------------------------------------------------------------------------------------------\n')

        # calculate sensitivity (recall of positive class for binary classification)
        temp = str(round(cr['1']['recall'],2))
        print('Sensitivity/ ability to correctly classifiy to Accident class is: {}'.format(temp))
    
        # calculate specificity (recall of negative class for binary classification)
        temp = str(round(cr['0']['recall'],2))
        print('Specificity/ ability to correctly classifiy to Non-Accident class is: {}'.format(temp))
        print('\n------------------------------------------------------------------------------------------\n')

        # calculate f1-beta score:
        print('Fbeta score with beta = 1.5 is: {}'.format(str(round(fbeta_score(y_true, y_pred,beta = 1.4),2))))
        print('\n------------------------------------------------------------------------------------------\n')

        # Confusion matrix:

        if normalize == False:
            cm = confusion_matrix(y_true, y_pred)
            disp = ConfusionMatrixDisplay(cm, display_labels = ["Non-Accident", 'Accident'])
            disp.plot()
            plt.title('Confusion Matrix')
            plt.show()
            print('\n------------------------------------------------------------------------------------------\n')
        else:
            cm = confusion_matrix(y_true, y_pred, normalize='all')
            disp = ConfusionMatrixDisplay(cm, display_labels = ["Non-Accident", 'Accident'])
            disp.plot()
            plt.title('Confusion Matrix')
            plt.show()
            print('\n------------------------------------------------------------------------------------------\n')

        # ROC curve:
        fpr, tpr, thresholds = roc_curve(y_true, y_pred)
        plt.plot(fpr, tpr, marker = 'o')
        plt.xlabel('% of Non-Accidents incorrectly classified')
        plt.ylabel('% of Accidents correctly classified')
        plt.title('ROC Curve')
        plt.show()
        print('\n------------------------------------------------------------------------------------------\n')
        temp = round(auc(fpr, tpr),2)
        print('AUC score is: {}'.format(temp))

    return

# %% [markdown]
# # Fitting a Gradient Boosting Classifier

# %% [markdown]
# ## On grayscale images

# %% [markdown]
# ## Scale the data

# %%
scaler = StandardScaler()
X_train_gray_sc = scaler.fit_transform(X_final_train_gray)
X_test_gray_sc = scaler.transform(X_test_gray)

# %%
X_train_gray_sc.shape, X_test_gray_sc.shape
# Out:
# ((889, 98), (100, 98))

# %% [markdown]
# ### Let's formally do hyper-parameter tuning, using Bayes Optimization and Grid Search. The default parameters are also an option to use for both Bayes and Grid search CV, if they indeed have the best generalizing capability, then it will get detected.

# %%
parameters = {'loss': ['log_loss', 'exponential'], 'learning_rate': Real(0.0001, 10, 'uniform'), 'n_estimators': Integer(10,200, 'uniform'),
              'subsample': Real(0.2,1, 'uniform'),'criterion' : ['friedman_mse', 'squared_error'], 'max_depth': Integer(2,1e10,prior='uniform'),
              'min_samples_split': Integer(2, 10, prior='uniform'), 'min_samples_leaf': Integer(1, 10, prior='uniform'),
              'min_weight_fraction_leaf':Real(0,0.5,prior='uniform'), 'max_features':[None,'sqrt','log2'],
              'max_leaf_nodes': Integer(5, 30, prior='uniform'), 'min_impurity_decrease':Real(0, 2, 'uniform'),
              'ccp_alpha':Real(0,1,'uniform')} 
fbeta_scorer = make_scorer(fbeta_score, beta = 1.4)

# %%
opt = BayesSearchCV(GradientBoostingClassifier(random_state = 5000), parameters, n_iter = 200, scoring = fbeta_scorer, verbose = 5, random_state = 5000, cv = 3)

np.int = int  # numpy doesn't have int attribute now, to avoid an error in existing code, need to use int in place of this.

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    opt.fit(X_train_gray_sc, y_train_final)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8521957323049895, criterion=friedman_mse, learning_rate=9.72299867812434, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=30, min_impurity_decrease=0.08871951194118723, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.48571129758953246, n_estimators=86, subsample=0.5448734369448387;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.8521957323049895, criterion=friedman_mse, learning_rate=9.72299867812434, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=30, min_impurity_decrease=0.08871951194118723, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.48571129758953246, n_estimators=86, subsample=0.5448734369448387;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.8521957323049895, criterion=friedman_mse, learning_rate=9.72299867812434, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=30, min_impurity_decrease=0.08871951194118723, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.48571129758953246, n_estimators=86, subsample=0.5448734369448387;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.6159027912677043, criterion=squared_error, learning_rate=5.636331772587529, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=9, min_impurity_decrease=0.6258063321783999, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.03911199716650494, n_estimators=40, subsample=0.7248335367296737;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.6159027912677043, criterion=squared_error, learning_rate=5.636331772587529, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=9, min_impurity_decrease=0.6258063321783999, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.03911199716650494, n_estimators=40, subsample=0.7248335367296737;, score=0.411 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.6159027912677043, criterion=squared_error, learning_rate=5.636331772587529, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=9, min_impurity_decrease=0.6258063321783999, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.03911199716650494, n_estimators=40, subsample=0.7248335367296737;, score=0.593 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9597329302645083, criterion=friedman_mse, learning_rate=7.454428567670615, loss=exponential, max_depth=504636465, max_features=sqrt, max_leaf_nodes=27, min_impurity_decrease=1.5640139390095862, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.1733039061577856, n_estimators=157, subsample=0.7841650060481504;, score=0.000 total time=   0.7s
# [CV 2/3] END ccp_alpha=0.9597329302645083, criterion=friedman_mse, learning_rate=7.454428567670615, loss=exponential, max_depth=504636465, max_features=sqrt, max_leaf_nodes=27, min_impurity_decrease=1.5640139390095862, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.1733039061577856, n_estimators=157, subsample=0.7841650060481504;, score=0.000 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.9597329302645083, criterion=friedman_mse, learning_rate=7.454428567670615, loss=exponential, max_depth=504636465, max_features=sqrt, max_leaf_nodes=27, min_impurity_decrease=1.5640139390095862, min_samples_leaf=3, min_samples_split=3, min_weight_fraction_leaf=0.1733039061577856, n_estimators=157, subsample=0.7841650060481504;, score=0.000 total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.01596295260258274, criterion=squared_error, learning_rate=5.57901407197725, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=24, min_impurity_decrease=1.7554402959960687, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.3725053736195426, n_estimators=142, subsample=0.32148025253935575;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.01596295260258274, criterion=squared_error, learning_rate=5.57901407197725, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=24, min_impurity_decrease=1.7554402959960687, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.3725053736195426, n_estimators=142, subsample=0.32148025253935575;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.01596295260258274, criterion=squared_error, learning_rate=5.57901407197725, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=24, min_impurity_decrease=1.7554402959960687, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.3725053736195426, n_estimators=142, subsample=0.32148025253935575;, score=0.000 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9169093057166782, criterion=squared_error, learning_rate=6.405434107505944, loss=log_loss, max_depth=1078524613, max_features=None, max_leaf_nodes=18, min_impurity_decrease=1.9925430205477954, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.20338203988575532, n_estimators=129, subsample=0.24610368848281142;, score=0.000 total time=   0.9s
# [CV 2/3] END ccp_alpha=0.9169093057166782, criterion=squared_error, learning_rate=6.405434107505944, loss=log_loss, max_depth=1078524613, max_features=None, max_leaf_nodes=18, min_impurity_decrease=1.9925430205477954, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.20338203988575532, n_estimators=129, subsample=0.24610368848281142;, score=0.000 total time=   0.8s
# [CV 3/3] END ccp_alpha=0.9169093057166782, criterion=squared_error, learning_rate=6.405434107505944, loss=log_loss, max_depth=1078524613, max_features=None, max_leaf_nodes=18, min_impurity_decrease=1.9925430205477954, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.20338203988575532, n_estimators=129, subsample=0.24610368848281142;, score=0.000 total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.4860784517570129, criterion=friedman_mse, learning_rate=8.496343538603904, loss=exponential, max_depth=756821989, max_features=log2, max_leaf_nodes=9, min_impurity_decrease=1.6990901019378648, min_samples_leaf=9, min_samples_split=3, min_weight_fraction_leaf=0.18414244333483068, n_estimators=121, subsample=0.7355768042763937;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.4860784517570129, criterion=friedman_mse, learning_rate=8.496343538603904, loss=exponential, max_depth=756821989, max_features=log2, max_leaf_nodes=9, min_impurity_decrease=1.6990901019378648, min_samples_leaf=9, min_samples_split=3, min_weight_fraction_leaf=0.18414244333483068, n_estimators=121, subsample=0.7355768042763937;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.4860784517570129, criterion=friedman_mse, learning_rate=8.496343538603904, loss=exponential, max_depth=756821989, max_features=log2, max_leaf_nodes=9, min_impurity_decrease=1.6990901019378648, min_samples_leaf=9, min_samples_split=3, min_weight_fraction_leaf=0.18414244333483068, n_estimators=121, subsample=0.7355768042763937;, score=0.000 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.3650025221738032, criterion=friedman_mse, learning_rate=4.5426439326324735, loss=exponential, max_depth=1099806137, max_features=sqrt, max_leaf_nodes=13, min_impurity_decrease=1.9096596504529677, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.4081382851998662, n_estimators=136, subsample=0.3201272554594735;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.3650025221738032, criterion=friedman_mse, learning_rate=4.5426439326324735, loss=exponential, max_depth=1099806137, max_features=sqrt, max_leaf_nodes=13, min_impurity_decrease=1.9096596504529677, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.4081382851998662, n_estimators=136, subsample=0.3201272554594735;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.3650025221738032, criterion=friedman_mse, learning_rate=4.5426439326324735, loss=exponential, max_depth=1099806137, max_features=sqrt, max_leaf_nodes=13, min_impurity_decrease=1.9096596504529677, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.4081382851998662, n_estimators=136, subsample=0.3201272554594735;, score=0.722 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.27911391973795013, criterion=friedman_mse, learning_rate=7.934747943397221, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.9684424477356999, min_samples_leaf=8, min_samples_split=4, min_weight_fraction_leaf=0.15643256302333278, n_estimators=12, subsample=0.5558775336687491;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.27911391973795013, criterion=friedman_mse, learning_rate=7.934747943397221, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.9684424477356999, min_samples_leaf=8, min_samples_split=4, min_weight_fraction_leaf=0.15643256302333278, n_estimators=12, subsample=0.5558775336687491;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.27911391973795013, criterion=friedman_mse, learning_rate=7.934747943397221, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.9684424477356999, min_samples_leaf=8, min_samples_split=4, min_weight_fraction_leaf=0.15643256302333278, n_estimators=12, subsample=0.5558775336687491;, score=0.000 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8499984257164044, criterion=squared_error, learning_rate=9.861839918285048, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=18, min_impurity_decrease=1.9910936424786543, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.20884468640225157, n_estimators=106, subsample=0.29206263133348204;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.8499984257164044, criterion=squared_error, learning_rate=9.861839918285048, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=18, min_impurity_decrease=1.9910936424786543, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.20884468640225157, n_estimators=106, subsample=0.29206263133348204;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.8499984257164044, criterion=squared_error, learning_rate=9.861839918285048, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=18, min_impurity_decrease=1.9910936424786543, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.20884468640225157, n_estimators=106, subsample=0.29206263133348204;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.34360856641960197, criterion=squared_error, learning_rate=4.313562908863196, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=9, min_impurity_decrease=1.1675109574572935, min_samples_leaf=2, min_samples_split=7, min_weight_fraction_leaf=0.41192173693157547, n_estimators=32, subsample=0.6037381946108096;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.34360856641960197, criterion=squared_error, learning_rate=4.313562908863196, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=9, min_impurity_decrease=1.1675109574572935, min_samples_leaf=2, min_samples_split=7, min_weight_fraction_leaf=0.41192173693157547, n_estimators=32, subsample=0.6037381946108096;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.34360856641960197, criterion=squared_error, learning_rate=4.313562908863196, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=9, min_impurity_decrease=1.1675109574572935, min_samples_leaf=2, min_samples_split=7, min_weight_fraction_leaf=0.41192173693157547, n_estimators=32, subsample=0.6037381946108096;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=1.0, criterion=squared_error, learning_rate=10.0, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=8, min_impurity_decrease=0.7916394891569709, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=10, subsample=0.30006275220069595;, score=0.082 total time=   0.0s
# [CV 2/3] END ccp_alpha=1.0, criterion=squared_error, learning_rate=10.0, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=8, min_impurity_decrease=0.7916394891569709, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=10, subsample=0.30006275220069595;, score=0.323 total time=   0.0s
# [CV 3/3] END ccp_alpha=1.0, criterion=squared_error, learning_rate=10.0, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=8, min_impurity_decrease=0.7916394891569709, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=10, subsample=0.30006275220069595;, score=0.471 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.5290228037549499, criterion=friedman_mse, learning_rate=5.115461626915464, loss=exponential, max_depth=858489451, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.5370501777927736, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.43825679257435346, n_estimators=132, subsample=0.3425142828222484;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.5290228037549499, criterion=friedman_mse, learning_rate=5.115461626915464, loss=exponential, max_depth=858489451, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.5370501777927736, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.43825679257435346, n_estimators=132, subsample=0.3425142828222484;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.5290228037549499, criterion=friedman_mse, learning_rate=5.115461626915464, loss=exponential, max_depth=858489451, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.5370501777927736, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.43825679257435346, n_estimators=132, subsample=0.3425142828222484;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8671429137601838, criterion=squared_error, learning_rate=7.662866171698561, loss=exponential, max_depth=2, max_features=None, max_leaf_nodes=30, min_impurity_decrease=0.23708700355330858, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.24677775613758945, n_estimators=200, subsample=1.0;, score=0.000 total time=   4.9s
# [CV 2/3] END ccp_alpha=0.8671429137601838, criterion=squared_error, learning_rate=7.662866171698561, loss=exponential, max_depth=2, max_features=None, max_leaf_nodes=30, min_impurity_decrease=0.23708700355330858, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.24677775613758945, n_estimators=200, subsample=1.0;, score=0.000 total time=   7.7s
# [CV 3/3] END ccp_alpha=0.8671429137601838, criterion=squared_error, learning_rate=7.662866171698561, loss=exponential, max_depth=2, max_features=None, max_leaf_nodes=30, min_impurity_decrease=0.23708700355330858, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.24677775613758945, n_estimators=200, subsample=1.0;, score=0.000 total time=   8.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.5981729001688892, criterion=friedman_mse, learning_rate=1.7370873678416192, loss=exponential, max_depth=2, max_features=None, max_leaf_nodes=26, min_impurity_decrease=0.0, min_samples_leaf=7, min_samples_split=8, min_weight_fraction_leaf=0.5, n_estimators=72, subsample=0.4798885744272674;, score=0.000 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.5981729001688892, criterion=friedman_mse, learning_rate=1.7370873678416192, loss=exponential, max_depth=2, max_features=None, max_leaf_nodes=26, min_impurity_decrease=0.0, min_samples_leaf=7, min_samples_split=8, min_weight_fraction_leaf=0.5, n_estimators=72, subsample=0.4798885744272674;, score=0.000 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.5981729001688892, criterion=friedman_mse, learning_rate=1.7370873678416192, loss=exponential, max_depth=2, max_features=None, max_leaf_nodes=26, min_impurity_decrease=0.0, min_samples_leaf=7, min_samples_split=8, min_weight_fraction_leaf=0.5, n_estimators=72, subsample=0.4798885744272674;, score=0.000 total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8729414085201327, criterion=friedman_mse, learning_rate=9.887710773117355, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=30, min_impurity_decrease=0.09656668255756662, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.5, n_estimators=84, subsample=0.5188420103410417;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.8729414085201327, criterion=friedman_mse, learning_rate=9.887710773117355, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=30, min_impurity_decrease=0.09656668255756662, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.5, n_estimators=84, subsample=0.5188420103410417;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.8729414085201327, criterion=friedman_mse, learning_rate=9.887710773117355, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=30, min_impurity_decrease=0.09656668255756662, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.5, n_estimators=84, subsample=0.5188420103410417;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.6104840955333148, criterion=squared_error, learning_rate=6.472855740298038, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=15, min_impurity_decrease=1.3502080467938298, min_samples_leaf=4, min_samples_split=6, min_weight_fraction_leaf=0.15079741882541375, n_estimators=89, subsample=0.6314232468116574;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.6104840955333148, criterion=squared_error, learning_rate=6.472855740298038, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=15, min_impurity_decrease=1.3502080467938298, min_samples_leaf=4, min_samples_split=6, min_weight_fraction_leaf=0.15079741882541375, n_estimators=89, subsample=0.6314232468116574;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.6104840955333148, criterion=squared_error, learning_rate=6.472855740298038, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=15, min_impurity_decrease=1.3502080467938298, min_samples_leaf=4, min_samples_split=6, min_weight_fraction_leaf=0.15079741882541375, n_estimators=89, subsample=0.6314232468116574;, score=0.000 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8272004006850944, criterion=squared_error, learning_rate=9.976949377462617, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=28, min_impurity_decrease=2.0, min_samples_leaf=4, min_samples_split=8, min_weight_fraction_leaf=0.33531809796271095, n_estimators=185, subsample=0.2;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.8272004006850944, criterion=squared_error, learning_rate=9.976949377462617, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=28, min_impurity_decrease=2.0, min_samples_leaf=4, min_samples_split=8, min_weight_fraction_leaf=0.33531809796271095, n_estimators=185, subsample=0.2;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.8272004006850944, criterion=squared_error, learning_rate=9.976949377462617, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=28, min_impurity_decrease=2.0, min_samples_leaf=4, min_samples_split=8, min_weight_fraction_leaf=0.33531809796271095, n_estimators=185, subsample=0.2;, score=0.000 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8524979019500555, criterion=friedman_mse, learning_rate=8.357303016839724, loss=exponential, max_depth=1790187084, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.20397677010499654, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.5, n_estimators=53, subsample=0.5054331087756083;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.8524979019500555, criterion=friedman_mse, learning_rate=8.357303016839724, loss=exponential, max_depth=1790187084, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.20397677010499654, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.5, n_estimators=53, subsample=0.5054331087756083;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.8524979019500555, criterion=friedman_mse, learning_rate=8.357303016839724, loss=exponential, max_depth=1790187084, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=0.20397677010499654, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.5, n_estimators=53, subsample=0.5054331087756083;, score=0.000 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8732908230961182, criterion=squared_error, learning_rate=9.835261013503962, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=24, min_impurity_decrease=1.078338592582139, min_samples_leaf=5, min_samples_split=4, min_weight_fraction_leaf=0.3517269114519959, n_estimators=95, subsample=0.38575910184896706;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.8732908230961182, criterion=squared_error, learning_rate=9.835261013503962, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=24, min_impurity_decrease=1.078338592582139, min_samples_leaf=5, min_samples_split=4, min_weight_fraction_leaf=0.3517269114519959, n_estimators=95, subsample=0.38575910184896706;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.8732908230961182, criterion=squared_error, learning_rate=9.835261013503962, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=24, min_impurity_decrease=1.078338592582139, min_samples_leaf=5, min_samples_split=4, min_weight_fraction_leaf=0.3517269114519959, n_estimators=95, subsample=0.38575910184896706;, score=0.000 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8185199496619605, criterion=squared_error, learning_rate=9.302221742443521, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=17, min_impurity_decrease=1.8063552942863352, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.18526525725351012, n_estimators=97, subsample=0.3495000804141786;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.8185199496619605, criterion=squared_error, learning_rate=9.302221742443521, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=17, min_impurity_decrease=1.8063552942863352, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.18526525725351012, n_estimators=97, subsample=0.3495000804141786;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.8185199496619605, criterion=squared_error, learning_rate=9.302221742443521, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=17, min_impurity_decrease=1.8063552942863352, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.18526525725351012, n_estimators=97, subsample=0.3495000804141786;, score=0.000 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.23015527805390393, criterion=squared_error, learning_rate=9.966804707217976, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=19, min_impurity_decrease=1.01194734416559, min_samples_leaf=7, min_samples_split=4, min_weight_fraction_leaf=0.1186767385564359, n_estimators=107, subsample=0.7997921824290968;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.23015527805390393, criterion=squared_error, learning_rate=9.966804707217976, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=19, min_impurity_decrease=1.01194734416559, min_samples_leaf=7, min_samples_split=4, min_weight_fraction_leaf=0.1186767385564359, n_estimators=107, subsample=0.7997921824290968;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.23015527805390393, criterion=squared_error, learning_rate=9.966804707217976, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=19, min_impurity_decrease=1.01194734416559, min_samples_leaf=7, min_samples_split=4, min_weight_fraction_leaf=0.1186767385564359, n_estimators=107, subsample=0.7997921824290968;, score=0.000 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.544641380962872, criterion=friedman_mse, learning_rate=4.579927478020354, loss=exponential, max_depth=987293777, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.636401670504292, min_samples_leaf=7, min_samples_split=8, min_weight_fraction_leaf=0.49008424132816547, n_estimators=149, subsample=0.2985902161472168;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.544641380962872, criterion=friedman_mse, learning_rate=4.579927478020354, loss=exponential, max_depth=987293777, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.636401670504292, min_samples_leaf=7, min_samples_split=8, min_weight_fraction_leaf=0.49008424132816547, n_estimators=149, subsample=0.2985902161472168;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.544641380962872, criterion=friedman_mse, learning_rate=4.579927478020354, loss=exponential, max_depth=987293777, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.636401670504292, min_samples_leaf=7, min_samples_split=8, min_weight_fraction_leaf=0.49008424132816547, n_estimators=149, subsample=0.2985902161472168;, score=0.000 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.5032573142717239, criterion=friedman_mse, learning_rate=2.7686804637682045, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=18, min_impurity_decrease=1.8660373003474289, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.0035748687337672567, n_estimators=141, subsample=0.24011903020342795;, score=0.011 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.5032573142717239, criterion=friedman_mse, learning_rate=2.7686804637682045, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=18, min_impurity_decrease=1.8660373003474289, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.0035748687337672567, n_estimators=141, subsample=0.24011903020342795;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.5032573142717239, criterion=friedman_mse, learning_rate=2.7686804637682045, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=18, min_impurity_decrease=1.8660373003474289, min_samples_leaf=4, min_samples_split=5, min_weight_fraction_leaf=0.0035748687337672567, n_estimators=141, subsample=0.24011903020342795;, score=0.000 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9805229856274381, criterion=squared_error, learning_rate=7.5241388240804445, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=18, min_impurity_decrease=0.452512547456167, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.004863246232431267, n_estimators=131, subsample=0.4872174771451072;, score=0.532 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.9805229856274381, criterion=squared_error, learning_rate=7.5241388240804445, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=18, min_impurity_decrease=0.452512547456167, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.004863246232431267, n_estimators=131, subsample=0.4872174771451072;, score=0.722 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.9805229856274381, criterion=squared_error, learning_rate=7.5241388240804445, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=18, min_impurity_decrease=0.452512547456167, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.004863246232431267, n_estimators=131, subsample=0.4872174771451072;, score=0.538 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.05775353909002118, criterion=friedman_mse, learning_rate=4.736192623790393, loss=exponential, max_depth=1565753811, max_features=sqrt, max_leaf_nodes=17, min_impurity_decrease=1.933611140613537, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.2577159969740001, n_estimators=144, subsample=0.28975519033597164;, score=0.601 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.05775353909002118, criterion=friedman_mse, learning_rate=4.736192623790393, loss=exponential, max_depth=1565753811, max_features=sqrt, max_leaf_nodes=17, min_impurity_decrease=1.933611140613537, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.2577159969740001, n_estimators=144, subsample=0.28975519033597164;, score=0.626 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.05775353909002118, criterion=friedman_mse, learning_rate=4.736192623790393, loss=exponential, max_depth=1565753811, max_features=sqrt, max_leaf_nodes=17, min_impurity_decrease=1.933611140613537, min_samples_leaf=1, min_samples_split=8, min_weight_fraction_leaf=0.2577159969740001, n_estimators=144, subsample=0.28975519033597164;, score=0.739 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.15590159308134152, criterion=friedman_mse, learning_rate=3.644011377830495, loss=log_loss, max_depth=1585153353, max_features=None, max_leaf_nodes=25, min_impurity_decrease=1.8695815857031313, min_samples_leaf=2, min_samples_split=8, min_weight_fraction_leaf=0.3063718601770113, n_estimators=165, subsample=0.37247317419878245;, score=0.723 total time=   2.3s
# [CV 2/3] END ccp_alpha=0.15590159308134152, criterion=friedman_mse, learning_rate=3.644011377830495, loss=log_loss, max_depth=1585153353, max_features=None, max_leaf_nodes=25, min_impurity_decrease=1.8695815857031313, min_samples_leaf=2, min_samples_split=8, min_weight_fraction_leaf=0.3063718601770113, n_estimators=165, subsample=0.37247317419878245;, score=0.721 total time=   2.3s
# [CV 3/3] END ccp_alpha=0.15590159308134152, criterion=friedman_mse, learning_rate=3.644011377830495, loss=log_loss, max_depth=1585153353, max_features=None, max_leaf_nodes=25, min_impurity_decrease=1.8695815857031313, min_samples_leaf=2, min_samples_split=8, min_weight_fraction_leaf=0.3063718601770113, n_estimators=165, subsample=0.37247317419878245;, score=0.721 total time=   2.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.37584816527618636, criterion=friedman_mse, learning_rate=9.905273152026913, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=12, min_impurity_decrease=1.996276620818567, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.161261974315659, n_estimators=101, subsample=0.40188539008303575;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.37584816527618636, criterion=friedman_mse, learning_rate=9.905273152026913, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=12, min_impurity_decrease=1.996276620818567, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.161261974315659, n_estimators=101, subsample=0.40188539008303575;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.37584816527618636, criterion=friedman_mse, learning_rate=9.905273152026913, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=12, min_impurity_decrease=1.996276620818567, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.161261974315659, n_estimators=101, subsample=0.40188539008303575;, score=0.000 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.794787528574155, criterion=squared_error, learning_rate=10.0, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=29, min_impurity_decrease=1.6207060175977737, min_samples_leaf=2, min_samples_split=9, min_weight_fraction_leaf=0.22335479595833996, n_estimators=141, subsample=0.27388285918326505;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.794787528574155, criterion=squared_error, learning_rate=10.0, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=29, min_impurity_decrease=1.6207060175977737, min_samples_leaf=2, min_samples_split=9, min_weight_fraction_leaf=0.22335479595833996, n_estimators=141, subsample=0.27388285918326505;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.794787528574155, criterion=squared_error, learning_rate=10.0, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=29, min_impurity_decrease=1.6207060175977737, min_samples_leaf=2, min_samples_split=9, min_weight_fraction_leaf=0.22335479595833996, n_estimators=141, subsample=0.27388285918326505;, score=0.000 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.6842972301859293, criterion=squared_error, learning_rate=7.93819696880386, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=6, min_impurity_decrease=1.7650744379899606, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.2231556222847081, n_estimators=94, subsample=0.2918579167663797;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.6842972301859293, criterion=squared_error, learning_rate=7.93819696880386, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=6, min_impurity_decrease=1.7650744379899606, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.2231556222847081, n_estimators=94, subsample=0.2918579167663797;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.6842972301859293, criterion=squared_error, learning_rate=7.93819696880386, loss=exponential, max_depth=2, max_features=sqrt, max_leaf_nodes=6, min_impurity_decrease=1.7650744379899606, min_samples_leaf=9, min_samples_split=5, min_weight_fraction_leaf=0.2231556222847081, n_estimators=94, subsample=0.2918579167663797;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.29315165190701736, criterion=friedman_mse, learning_rate=2.5625690862058597, loss=exponential, max_depth=42271, max_features=sqrt, max_leaf_nodes=16, min_impurity_decrease=1.0358646608853916, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.42105083236181373, n_estimators=196, subsample=0.4599068476035239;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.29315165190701736, criterion=friedman_mse, learning_rate=2.5625690862058597, loss=exponential, max_depth=42271, max_features=sqrt, max_leaf_nodes=16, min_impurity_decrease=1.0358646608853916, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.42105083236181373, n_estimators=196, subsample=0.4599068476035239;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.29315165190701736, criterion=friedman_mse, learning_rate=2.5625690862058597, loss=exponential, max_depth=42271, max_features=sqrt, max_leaf_nodes=16, min_impurity_decrease=1.0358646608853916, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.42105083236181373, n_estimators=196, subsample=0.4599068476035239;, score=0.721 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8267045802440095, criterion=squared_error, learning_rate=9.61747221103593, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=16, min_impurity_decrease=1.9712122142874657, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.21277571763626263, n_estimators=105, subsample=0.2868404408964119;, score=0.000 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.8267045802440095, criterion=squared_error, learning_rate=9.61747221103593, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=16, min_impurity_decrease=1.9712122142874657, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.21277571763626263, n_estimators=105, subsample=0.2868404408964119;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.8267045802440095, criterion=squared_error, learning_rate=9.61747221103593, loss=exponential, max_depth=2, max_features=log2, max_leaf_nodes=16, min_impurity_decrease=1.9712122142874657, min_samples_leaf=5, min_samples_split=5, min_weight_fraction_leaf=0.21277571763626263, n_estimators=105, subsample=0.2868404408964119;, score=0.000 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9348308852009575, criterion=friedman_mse, learning_rate=1.2378296624314145, loss=log_loss, max_depth=201, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.1383222324685454, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.114044475939427, n_estimators=190, subsample=0.2953479855151657;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.9348308852009575, criterion=friedman_mse, learning_rate=1.2378296624314145, loss=log_loss, max_depth=201, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.1383222324685454, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.114044475939427, n_estimators=190, subsample=0.2953479855151657;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.9348308852009575, criterion=friedman_mse, learning_rate=1.2378296624314145, loss=log_loss, max_depth=201, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.1383222324685454, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.114044475939427, n_estimators=190, subsample=0.2953479855151657;, score=0.721 total time=   0.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.19284880671975624, criterion=friedman_mse, learning_rate=5.491435759285796, loss=exponential, max_depth=369712040, max_features=sqrt, max_leaf_nodes=15, min_impurity_decrease=1.4099557693390394, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.41365177359138083, n_estimators=115, subsample=0.34745135907674896;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.19284880671975624, criterion=friedman_mse, learning_rate=5.491435759285796, loss=exponential, max_depth=369712040, max_features=sqrt, max_leaf_nodes=15, min_impurity_decrease=1.4099557693390394, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.41365177359138083, n_estimators=115, subsample=0.34745135907674896;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.19284880671975624, criterion=friedman_mse, learning_rate=5.491435759285796, loss=exponential, max_depth=369712040, max_features=sqrt, max_leaf_nodes=15, min_impurity_decrease=1.4099557693390394, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.41365177359138083, n_estimators=115, subsample=0.34745135907674896;, score=0.000 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.1779792897681812, criterion=friedman_mse, learning_rate=5.190824700066192, loss=exponential, max_depth=614051, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.5291728121851158, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.19308992682721868, n_estimators=131, subsample=0.8124928690111306;, score=0.032 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.1779792897681812, criterion=friedman_mse, learning_rate=5.190824700066192, loss=exponential, max_depth=614051, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.5291728121851158, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.19308992682721868, n_estimators=131, subsample=0.8124928690111306;, score=0.032 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.1779792897681812, criterion=friedman_mse, learning_rate=5.190824700066192, loss=exponential, max_depth=614051, max_features=sqrt, max_leaf_nodes=20, min_impurity_decrease=1.5291728121851158, min_samples_leaf=7, min_samples_split=3, min_weight_fraction_leaf=0.19308992682721868, n_estimators=131, subsample=0.8124928690111306;, score=0.000 total time=   0.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.6592606664807146, criterion=friedman_mse, learning_rate=3.8221213526230056, loss=log_loss, max_depth=30412, max_features=sqrt, max_leaf_nodes=21, min_impurity_decrease=1.021979634437991, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.13954323076769537, n_estimators=155, subsample=0.3683659271246421;, score=0.723 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.6592606664807146, criterion=friedman_mse, learning_rate=3.8221213526230056, loss=log_loss, max_depth=30412, max_features=sqrt, max_leaf_nodes=21, min_impurity_decrease=1.021979634437991, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.13954323076769537, n_estimators=155, subsample=0.3683659271246421;, score=0.721 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.6592606664807146, criterion=friedman_mse, learning_rate=3.8221213526230056, loss=log_loss, max_depth=30412, max_features=sqrt, max_leaf_nodes=21, min_impurity_decrease=1.021979634437991, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.13954323076769537, n_estimators=155, subsample=0.3683659271246421;, score=0.721 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8602948829883286, criterion=friedman_mse, learning_rate=3.773931354934252, loss=exponential, max_depth=14739, max_features=log2, max_leaf_nodes=23, min_impurity_decrease=1.8951062121711448, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.24258649494500714, n_estimators=121, subsample=0.8860673278077629;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.8602948829883286, criterion=friedman_mse, learning_rate=3.773931354934252, loss=exponential, max_depth=14739, max_features=log2, max_leaf_nodes=23, min_impurity_decrease=1.8951062121711448, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.24258649494500714, n_estimators=121, subsample=0.8860673278077629;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.8602948829883286, criterion=friedman_mse, learning_rate=3.773931354934252, loss=exponential, max_depth=14739, max_features=log2, max_leaf_nodes=23, min_impurity_decrease=1.8951062121711448, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.24258649494500714, n_estimators=121, subsample=0.8860673278077629;, score=0.721 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.31708057785170557, criterion=friedman_mse, learning_rate=5.960582358648132, loss=exponential, max_depth=505080262, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=1.911067818943522, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.02186022699945118, n_estimators=96, subsample=0.5605381058624941;, score=0.748 total time=   1.0s
# [CV 2/3] END ccp_alpha=0.31708057785170557, criterion=friedman_mse, learning_rate=5.960582358648132, loss=exponential, max_depth=505080262, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=1.911067818943522, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.02186022699945118, n_estimators=96, subsample=0.5605381058624941;, score=0.702 total time=   0.9s
# [CV 3/3] END ccp_alpha=0.31708057785170557, criterion=friedman_mse, learning_rate=5.960582358648132, loss=exponential, max_depth=505080262, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=1.911067818943522, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.02186022699945118, n_estimators=96, subsample=0.5605381058624941;, score=0.617 total time=   1.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.6212926263165949, criterion=friedman_mse, learning_rate=4.143570109263492, loss=exponential, max_depth=1002, max_features=sqrt, max_leaf_nodes=9, min_impurity_decrease=1.0263108720473946, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.16292604652001377, n_estimators=94, subsample=0.8118567283209515;, score=0.723 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.6212926263165949, criterion=friedman_mse, learning_rate=4.143570109263492, loss=exponential, max_depth=1002, max_features=sqrt, max_leaf_nodes=9, min_impurity_decrease=1.0263108720473946, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.16292604652001377, n_estimators=94, subsample=0.8118567283209515;, score=0.721 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.6212926263165949, criterion=friedman_mse, learning_rate=4.143570109263492, loss=exponential, max_depth=1002, max_features=sqrt, max_leaf_nodes=9, min_impurity_decrease=1.0263108720473946, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.16292604652001377, n_estimators=94, subsample=0.8118567283209515;, score=0.721 total time=   0.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.6623063527951178, criterion=friedman_mse, learning_rate=6.073364892617672, loss=exponential, max_depth=8520419, max_features=sqrt, max_leaf_nodes=15, min_impurity_decrease=1.8433718207273475, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.5, n_estimators=55, subsample=0.8025902787963315;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.6623063527951178, criterion=friedman_mse, learning_rate=6.073364892617672, loss=exponential, max_depth=8520419, max_features=sqrt, max_leaf_nodes=15, min_impurity_decrease=1.8433718207273475, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.5, n_estimators=55, subsample=0.8025902787963315;, score=0.000 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.6623063527951178, criterion=friedman_mse, learning_rate=6.073364892617672, loss=exponential, max_depth=8520419, max_features=sqrt, max_leaf_nodes=15, min_impurity_decrease=1.8433718207273475, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.5, n_estimators=55, subsample=0.8025902787963315;, score=0.000 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.8998423100879468, criterion=friedman_mse, learning_rate=1.7983612086536633, loss=log_loss, max_depth=1665037766, max_features=sqrt, max_leaf_nodes=12, min_impurity_decrease=1.9122004962350043, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.4427827691634946, n_estimators=110, subsample=0.3499966112404196;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.8998423100879468, criterion=friedman_mse, learning_rate=1.7983612086536633, loss=log_loss, max_depth=1665037766, max_features=sqrt, max_leaf_nodes=12, min_impurity_decrease=1.9122004962350043, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.4427827691634946, n_estimators=110, subsample=0.3499966112404196;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.8998423100879468, criterion=friedman_mse, learning_rate=1.7983612086536633, loss=log_loss, max_depth=1665037766, max_features=sqrt, max_leaf_nodes=12, min_impurity_decrease=1.9122004962350043, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.4427827691634946, n_estimators=110, subsample=0.3499966112404196;, score=0.000 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.5008625720886712, criterion=friedman_mse, learning_rate=8.24466449991403, loss=exponential, max_depth=1106175814, max_features=sqrt, max_leaf_nodes=15, min_impurity_decrease=1.5474161372501056, min_samples_leaf=7, min_samples_split=7, min_weight_fraction_leaf=0.18118676461031585, n_estimators=64, subsample=0.7529407203666063;, score=0.723 total time=   0.2s
# ...
# [CV 3/3] END ccp_alpha=0.7813301876545542, criterion=squared_error, learning_rate=4.286623185787889, loss=log_loss, max_depth=1854200, max_features=sqrt, max_leaf_nodes=11, min_impurity_decrease=1.8506304768518491, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.11722766016714457, n_estimators=93, subsample=0.456878160746229;, score=0.721 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.2033927029037723, criterion=friedman_mse, learning_rate=5.624929705496447, loss=log_loss, max_depth=8337419, max_features=sqrt, max_leaf_nodes=25, min_impurity_decrease=0.9816875844936969, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.030088321542995716, n_estimators=200, subsample=0.5961627840414838;, score=0.723 total time=   2.6s
# [CV 2/3] END ccp_alpha=0.2033927029037723, criterion=friedman_mse, learning_rate=5.624929705496447, loss=log_loss, max_depth=8337419, max_features=sqrt, max_leaf_nodes=25, min_impurity_decrease=0.9816875844936969, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.030088321542995716, n_estimators=200, subsample=0.5961627840414838;, score=0.721 total time=   2.6s
# [CV 3/3] END ccp_alpha=0.2033927029037723, criterion=friedman_mse, learning_rate=5.624929705496447, loss=log_loss, max_depth=8337419, max_features=sqrt, max_leaf_nodes=25, min_impurity_decrease=0.9816875844936969, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.030088321542995716, n_estimators=200, subsample=0.5961627840414838;, score=0.721 total time=   2.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.998251116566779, criterion=friedman_mse, learning_rate=6.157671213278019, loss=log_loss, max_depth=1243647, max_features=sqrt, max_leaf_nodes=18, min_impurity_decrease=1.0984702691873882, min_samples_leaf=6, min_samples_split=4, min_weight_fraction_leaf=0.4641267793000219, n_estimators=173, subsample=0.642703973377644;, score=0.723 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.998251116566779, criterion=friedman_mse, learning_rate=6.157671213278019, loss=log_loss, max_depth=1243647, max_features=sqrt, max_leaf_nodes=18, min_impurity_decrease=1.0984702691873882, min_samples_leaf=6, min_samples_split=4, min_weight_fraction_leaf=0.4641267793000219, n_estimators=173, subsample=0.642703973377644;, score=0.721 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.998251116566779, criterion=friedman_mse, learning_rate=6.157671213278019, loss=log_loss, max_depth=1243647, max_features=sqrt, max_leaf_nodes=18, min_impurity_decrease=1.0984702691873882, min_samples_leaf=6, min_samples_split=4, min_weight_fraction_leaf=0.4641267793000219, n_estimators=173, subsample=0.642703973377644;, score=0.721 total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.5169663263578667, criterion=squared_error, learning_rate=6.499549634985988, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=18, min_impurity_decrease=0.9871140112259571, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.2125685923492302, n_estimators=161, subsample=0.6726574876613923;, score=0.723 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.5169663263578667, criterion=squared_error, learning_rate=6.499549634985988, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=18, min_impurity_decrease=0.9871140112259571, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.2125685923492302, n_estimators=161, subsample=0.6726574876613923;, score=0.721 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.5169663263578667, criterion=squared_error, learning_rate=6.499549634985988, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=18, min_impurity_decrease=0.9871140112259571, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.2125685923492302, n_estimators=161, subsample=0.6726574876613923;, score=0.721 total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.522081092935788, criterion=friedman_mse, learning_rate=4.494714903246752, loss=log_loss, max_depth=18221872, max_features=sqrt, max_leaf_nodes=22, min_impurity_decrease=0.35164312044619894, min_samples_leaf=9, min_samples_split=7, min_weight_fraction_leaf=0.1321348967034938, n_estimators=84, subsample=0.4101344350867972;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.522081092935788, criterion=friedman_mse, learning_rate=4.494714903246752, loss=log_loss, max_depth=18221872, max_features=sqrt, max_leaf_nodes=22, min_impurity_decrease=0.35164312044619894, min_samples_leaf=9, min_samples_split=7, min_weight_fraction_leaf=0.1321348967034938, n_estimators=84, subsample=0.4101344350867972;, score=0.000 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.522081092935788, criterion=friedman_mse, learning_rate=4.494714903246752, loss=log_loss, max_depth=18221872, max_features=sqrt, max_leaf_nodes=22, min_impurity_decrease=0.35164312044619894, min_samples_leaf=9, min_samples_split=7, min_weight_fraction_leaf=0.1321348967034938, n_estimators=84, subsample=0.4101344350867972;, score=0.721 total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.9158281809523867, criterion=friedman_mse, learning_rate=4.510390972915822, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=13, min_impurity_decrease=1.8236640829735569, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.3436301994395547, n_estimators=144, subsample=0.46953265296200625;, score=0.723 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.9158281809523867, criterion=friedman_mse, learning_rate=4.510390972915822, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=13, min_impurity_decrease=1.8236640829735569, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.3436301994395547, n_estimators=144, subsample=0.46953265296200625;, score=0.721 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.9158281809523867, criterion=friedman_mse, learning_rate=4.510390972915822, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=13, min_impurity_decrease=1.8236640829735569, min_samples_leaf=2, min_samples_split=5, min_weight_fraction_leaf=0.3436301994395547, n_estimators=144, subsample=0.46953265296200625;, score=0.721 total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.06367810400293321, criterion=squared_error, learning_rate=5.428150181842336, loss=log_loss, max_depth=592780, max_features=sqrt, max_leaf_nodes=30, min_impurity_decrease=0.5853381695176837, min_samples_leaf=3, min_samples_split=8, min_weight_fraction_leaf=0.45832089799706655, n_estimators=200, subsample=0.4668851916155029;, score=0.723 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.06367810400293321, criterion=squared_error, learning_rate=5.428150181842336, loss=log_loss, max_depth=592780, max_features=sqrt, max_leaf_nodes=30, min_impurity_decrease=0.5853381695176837, min_samples_leaf=3, min_samples_split=8, min_weight_fraction_leaf=0.45832089799706655, n_estimators=200, subsample=0.4668851916155029;, score=0.721 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.06367810400293321, criterion=squared_error, learning_rate=5.428150181842336, loss=log_loss, max_depth=592780, max_features=sqrt, max_leaf_nodes=30, min_impurity_decrease=0.5853381695176837, min_samples_leaf=3, min_samples_split=8, min_weight_fraction_leaf=0.45832089799706655, n_estimators=200, subsample=0.4668851916155029;, score=0.721 total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.7578313234959885, criterion=friedman_mse, learning_rate=4.355574282959396, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=1.2670018618381638, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.38773295822131704, n_estimators=68, subsample=0.4670574845010206;, score=0.723 total time=   0.1s
# [CV 2/3] END ccp_alpha=0.7578313234959885, criterion=friedman_mse, learning_rate=4.355574282959396, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=1.2670018618381638, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.38773295822131704, n_estimators=68, subsample=0.4670574845010206;, score=0.721 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.7578313234959885, criterion=friedman_mse, learning_rate=4.355574282959396, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=10, min_impurity_decrease=1.2670018618381638, min_samples_leaf=1, min_samples_split=10, min_weight_fraction_leaf=0.38773295822131704, n_estimators=68, subsample=0.4670574845010206;, score=0.721 total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.6953218485751731, criterion=squared_error, learning_rate=5.645751367769849, loss=log_loss, max_depth=8064502, max_features=sqrt, max_leaf_nodes=27, min_impurity_decrease=0.3830248698236497, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.29457570885785955, n_estimators=138, subsample=0.5912895241006094;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.6953218485751731, criterion=squared_error, learning_rate=5.645751367769849, loss=log_loss, max_depth=8064502, max_features=sqrt, max_leaf_nodes=27, min_impurity_decrease=0.3830248698236497, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.29457570885785955, n_estimators=138, subsample=0.5912895241006094;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.6953218485751731, criterion=squared_error, learning_rate=5.645751367769849, loss=log_loss, max_depth=8064502, max_features=sqrt, max_leaf_nodes=27, min_impurity_decrease=0.3830248698236497, min_samples_leaf=5, min_samples_split=10, min_weight_fraction_leaf=0.29457570885785955, n_estimators=138, subsample=0.5912895241006094;, score=0.721 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.4951052071295339, criterion=squared_error, learning_rate=3.921268428365272, loss=log_loss, max_depth=49643369, max_features=sqrt, max_leaf_nodes=24, min_impurity_decrease=0.009844184909367545, min_samples_leaf=2, min_samples_split=4, min_weight_fraction_leaf=0.474665954688943, n_estimators=182, subsample=0.3677505336485896;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.4951052071295339, criterion=squared_error, learning_rate=3.921268428365272, loss=log_loss, max_depth=49643369, max_features=sqrt, max_leaf_nodes=24, min_impurity_decrease=0.009844184909367545, min_samples_leaf=2, min_samples_split=4, min_weight_fraction_leaf=0.474665954688943, n_estimators=182, subsample=0.3677505336485896;, score=0.721 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.4951052071295339, criterion=squared_error, learning_rate=3.921268428365272, loss=log_loss, max_depth=49643369, max_features=sqrt, max_leaf_nodes=24, min_impurity_decrease=0.009844184909367545, min_samples_leaf=2, min_samples_split=4, min_weight_fraction_leaf=0.474665954688943, n_estimators=182, subsample=0.3677505336485896;, score=0.721 total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.533698833436404, criterion=friedman_mse, learning_rate=5.534908077207099, loss=log_loss, max_depth=1776858, max_features=sqrt, max_leaf_nodes=15, min_impurity_decrease=0.2658637462844102, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.14120189900610214, n_estimators=200, subsample=0.4665860752167487;, score=0.723 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.533698833436404, criterion=friedman_mse, learning_rate=5.534908077207099, loss=log_loss, max_depth=1776858, max_features=sqrt, max_leaf_nodes=15, min_impurity_decrease=0.2658637462844102, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.14120189900610214, n_estimators=200, subsample=0.4665860752167487;, score=0.721 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.533698833436404, criterion=friedman_mse, learning_rate=5.534908077207099, loss=log_loss, max_depth=1776858, max_features=sqrt, max_leaf_nodes=15, min_impurity_decrease=0.2658637462844102, min_samples_leaf=3, min_samples_split=5, min_weight_fraction_leaf=0.14120189900610214, n_estimators=200, subsample=0.4665860752167487;, score=0.721 total time=   0.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.2664995667767521, criterion=squared_error, learning_rate=4.4446559773942615, loss=log_loss, max_depth=3530955, max_features=sqrt, max_leaf_nodes=16, min_impurity_decrease=1.150827835244178, min_samples_leaf=8, min_samples_split=9, min_weight_fraction_leaf=0.41122804888509046, n_estimators=33, subsample=0.46855853219834054;, score=0.723 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.2664995667767521, criterion=squared_error, learning_rate=4.4446559773942615, loss=log_loss, max_depth=3530955, max_features=sqrt, max_leaf_nodes=16, min_impurity_decrease=1.150827835244178, min_samples_leaf=8, min_samples_split=9, min_weight_fraction_leaf=0.41122804888509046, n_estimators=33, subsample=0.46855853219834054;, score=0.721 total time=   0.0s
# [CV 3/3] END ccp_alpha=0.2664995667767521, criterion=squared_error, learning_rate=4.4446559773942615, loss=log_loss, max_depth=3530955, max_features=sqrt, max_leaf_nodes=16, min_impurity_decrease=1.150827835244178, min_samples_leaf=8, min_samples_split=9, min_weight_fraction_leaf=0.41122804888509046, n_estimators=33, subsample=0.46855853219834054;, score=0.721 total time=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.7203532807748583, criterion=squared_error, learning_rate=5.400399567371253, loss=log_loss, max_depth=7183418, max_features=sqrt, max_leaf_nodes=16, min_impurity_decrease=0.3821101200497642, min_samples_leaf=7, min_samples_split=5, min_weight_fraction_leaf=0.21898244689166851, n_estimators=179, subsample=0.5916443090195043;, score=0.723 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.7203532807748583, criterion=squared_error, learning_rate=5.400399567371253, loss=log_loss, max_depth=7183418, max_features=sqrt, max_leaf_nodes=16, min_impurity_decrease=0.3821101200497642, min_samples_leaf=7, min_samples_split=5, min_weight_fraction_leaf=0.21898244689166851, n_estimators=179, subsample=0.5916443090195043;, score=0.721 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.7203532807748583, criterion=squared_error, learning_rate=5.400399567371253, loss=log_loss, max_depth=7183418, max_features=sqrt, max_leaf_nodes=16, min_impurity_decrease=0.3821101200497642, min_samples_leaf=7, min_samples_split=5, min_weight_fraction_leaf=0.21898244689166851, n_estimators=179, subsample=0.5916443090195043;, score=0.721 total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ccp_alpha=0.16130737904015452, criterion=squared_error, learning_rate=9.813569390248622, loss=exponential, max_depth=6126182, max_features=None, max_leaf_nodes=30, min_impurity_decrease=0.7280003825319427, min_samples_leaf=5, min_samples_split=4, min_weight_fraction_leaf=0.279727262263999, n_estimators=150, subsample=0.30538964303498417;, score=0.723 total time=   1.6s
# [CV 2/3] END ccp_alpha=0.16130737904015452, criterion=squared_error, learning_rate=9.813569390248622, loss=exponential, max_depth=6126182, max_features=None, max_leaf_nodes=30, min_impurity_decrease=0.7280003825319427, min_samples_leaf=5, min_samples_split=4, min_weight_fraction_leaf=0.279727262263999, n_estimators=150, subsample=0.30538964303498417;, score=0.721 total time=   1.5s
# [CV 3/3] END ccp_alpha=0.16130737904015452, criterion=squared_error, learning_rate=9.813569390248622, loss=exponential, max_depth=6126182, max_features=None, max_leaf_nodes=30, min_impurity_decrease=0.7280003825319427, min_samples_leaf=5, min_samples_split=4, min_weight_fraction_leaf=0.279727262263999, n_estimators=150, subsample=0.30538964303498417;, score=0.721 total time=   1.7s

# %%
print('Best score using 3-fold cross validation:', round(opt.best_score_,2))
# Out:
# Best score using 3-fold cross validation: 0.88

# %%
print('Best parameters using 3-fold cross validation::', opt.best_params_)
# Out:
# Best parameters using 3-fold cross validation:: OrderedDict([('ccp_alpha', 0.0), ('criterion', 'gini'), ('max_depth', 1252442856), ('max_features', 'sqrt'), ('max_leaf_nodes', 29), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 10), ('min_weight_fraction_leaf', 0.0), ('n_estimators', 196)])

# %% [markdown]
# ## Trying Grid search CV

# %% [markdown]
# Some parameters whose function is similar to `max depth` have been dropped. Criterion has been set to default value `friedman mse`, documentation says, it's generally the best choice.

# %%
parameters = {'loss': ['log_loss', 'exponential'], 'learning_rate': [0.001, 0.01, 0.1, 0.4], 'n_estimators':[100, 200],
              'subsample': [0.45, 1], 'max_depth': [2,8,17,None],
               'max_features':[None,'sqrt','log2'],'max_leaf_nodes': [None, 2, 7, 16, 25],
              'ccp_alpha':[0, 0.3]} 
fbeta_scorer = make_scorer(fbeta_score, beta = 1.4)

# %%
opt_gs = GridSearchCV(GradientBoostingClassifier(random_state = 5000), parameters, scoring = fbeta_scorer, verbose = 5, cv = 3)

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    opt_gs.fit(X_train_gray_sc, y_train_final)
# Out:
# Fitting 3 folds for each of 3840 candidates, totalling 11520 fits
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.053 total time=   2.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   5.1s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   5.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.292 total time=   5.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.220 total time=   5.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.331 total time=   7.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.136 total time=   7.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.324 total time=  14.1s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.434 total time=  11.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.308 total time=  11.9s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   5.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   6.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   5.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.074 total time=   5.1s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.032 total time=   5.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   5.0s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=  11.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.136 total time=  11.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=  12.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.053 total time=   2.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   5.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   6.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.292 total time=   6.1s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.220 total time=   5.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.331 total time=   5.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.136 total time=   5.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.324 total time=  13.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.434 total time=  12.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.308 total time=  11.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.053 total time=   2.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.9s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   6.1s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   6.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.292 total time=   6.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.220 total time=   5.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.331 total time=   6.0s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.136 total time=   5.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.324 total time=  12.0s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.434 total time=  11.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.308 total time=  11.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.053 total time=   2.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   5.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   5.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.292 total time=   5.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.220 total time=   5.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.331 total time=   5.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.136 total time=   5.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.324 total time=  11.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.434 total time=  11.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.308 total time=  11.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.064 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.043 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.116 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.105 total time=   1.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.126 total time=   1.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.106 total time=   1.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   1.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   1.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   1.1s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.064 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.043 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.116 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.105 total time=   1.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.126 total time=   1.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.106 total time=   1.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.064 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.043 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.116 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.105 total time=   1.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.126 total time=   1.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.106 total time=   1.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   0.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.064 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.043 total time=   0.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.116 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.105 total time=   1.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.126 total time=   1.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.106 total time=   1.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.053 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.054 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.075 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.053 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.106 total time=   0.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.106 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.053 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.054 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.075 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.053 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.106 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.106 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.053 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.054 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.075 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.053 total time=   0.9s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.106 total time=   0.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.106 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.053 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.054 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.075 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.053 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.106 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.106 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.394 total time=   9.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.515 total time=   9.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.438 total time=   9.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.704 total time=  19.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.815 total time=  19.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.661 total time=  20.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.714 total time=  21.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.765 total time=  21.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.687 total time=  23.0s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.737 total time=  47.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.846 total time=  44.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.672 total time=  40.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   2.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   5.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   5.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   6.0s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.074 total time=   5.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.032 total time=   5.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   5.0s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=  11.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.136 total time=  11.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=  11.1s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.125 total time=   4.9s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.085 total time=   6.0s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.116 total time=   5.9s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.218 total time=  11.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.567 total time=  11.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.356 total time=  12.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.473 total time=  11.1s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.566 total time=  10.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.454 total time=  10.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.459 total time=  26.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.646 total time=  24.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.549 total time=  19.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.319 total time=   5.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.477 total time=   5.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.322 total time=   5.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.576 total time=  12.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.691 total time=  14.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.616 total time=  18.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.644 total time=  10.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.717 total time=  10.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.634 total time=  10.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.650 total time=  27.0s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.767 total time=  24.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.686 total time=  28.0s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.378 total time=   6.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.515 total time=   6.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.422 total time=   5.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.689 total time=  13.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.735 total time=  13.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.657 total time=  14.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.721 total time=  12.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.761 total time=  13.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.667 total time=  12.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.735 total time=  26.0s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.802 total time=  28.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.685 total time=  29.9s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.319 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.421 total time=   0.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.365 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.511 total time=   1.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.591 total time=   2.0s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.477 total time=   1.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.683 total time=   2.0s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.714 total time=   1.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.656 total time=   1.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.775 total time=   3.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.753 total time=   3.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.720 total time=   3.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   0.9s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   0.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.043 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.032 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.084 total time=   0.9s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.043 total time=   1.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.085 total time=   0.8s
# ...
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.000 total time=   1.5s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.000 total time=   1.5s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.000 total time=   1.4s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   1.0s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   1.1s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   1.0s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.9s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.9s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.8s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.000 total time=   2.0s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.000 total time=   2.0s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.000 total time=   1.9s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   1.1s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   1.1s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   1.1s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.000 total time=   1.0s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.000 total time=   1.0s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.000 total time=   1.0s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.000 total time=   2.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.000 total time=   2.3s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.000 total time=   2.2s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   1.0s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   1.0s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=100, subsample=1;, score=0.000 total time=   1.0s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.8s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.7s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.000 total time=   2.1s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.000 total time=   2.0s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=200, subsample=1;, score=0.000 total time=   1.9s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.0s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.1s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.1s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=100, subsample=1;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=200, subsample=1;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=100, subsample=1;, score=0.000 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.000 total time=   1.0s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.000 total time=   1.1s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=200, subsample=1;, score=0.000 total time=   1.0s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=100, subsample=1;, score=0.000 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.000 total time=   1.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.000 total time=   1.4s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=200, subsample=1;, score=0.000 total time=   1.4s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   0.7s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=100, subsample=1;, score=0.000 total time=   0.7s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.7s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.000 total time=   1.6s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.000 total time=   1.6s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=200, subsample=1;, score=0.000 total time=   1.5s

# %%
print('Best score using 3-fold cross validation:', round(opt_gs.best_score_,2))
# Out:
# Best score using 3-fold cross validation: 0.91

# %%
print('Best parameters using 3-fold cross validation:', opt_gs.best_params_)
# Out:
# Best parameters using 3-fold cross validation: {'ccp_alpha': 0, 'learning_rate': 0.1, 'loss': 'log_loss', 'max_depth': 8, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'n_estimators': 200, 'subsample': 1}

# %%
# n_estimators took value at the border of the grid, so extending the grid search in that direction for n_estimators

parameters = {'loss': ['log_loss', 'exponential'], 'learning_rate': [0.001, 0.01, 0.1, 0.4], 'n_estimators':[220],
              'subsample': [0.45, 1], 'max_depth': [2,8,17,None],
               'max_features':[None,'sqrt','log2'],'max_leaf_nodes': [None, 2, 7, 16, 25],
              'ccp_alpha':[0, 0.3]} 
fbeta_scorer = make_scorer(fbeta_score, beta = 1.4)

# %%
opt_gs2 = GridSearchCV(GradientBoostingClassifier(random_state = 5000), parameters, scoring = fbeta_scorer, verbose = 5, cv = 3)

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    opt_gs2.fit(X_train_gray_sc, y_train_final)
# Out:
# Fitting 3 folds for each of 1920 candidates, totalling 5760 fits
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.239 total time=   3.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.381 total time=   3.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.165 total time=   3.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.324 total time=   7.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.564 total time=   7.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.317 total time=   7.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.095 total time=   3.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.032 total time=   3.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   3.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.151 total time=   7.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.136 total time=   7.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   7.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.239 total time=   3.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.381 total time=   3.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.165 total time=   3.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.324 total time=   7.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.564 total time=   7.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.317 total time=   7.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.239 total time=   3.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.381 total time=   3.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.165 total time=   3.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.324 total time=   7.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.564 total time=   7.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.317 total time=   7.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.239 total time=   3.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.381 total time=   3.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.165 total time=   3.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.324 total time=   7.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.564 total time=   7.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.317 total time=   7.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.105 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.075 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.116 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.134 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.146 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.126 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.105 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.075 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.116 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.134 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.146 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.126 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.105 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.075 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.116 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.134 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.146 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.126 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.105 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.075 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.116 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.134 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.146 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.126 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.053 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.085 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.095 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.074 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.116 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.126 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.053 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.085 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.095 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.074 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.116 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.126 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.053 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.085 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.095 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.074 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.116 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.126 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.053 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.085 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.095 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.074 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.116 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=2, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.126 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.727 total time=  12.9s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.782 total time=  13.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.718 total time=  13.1s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.737 total time=  25.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.846 total time=  26.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.696 total time=  25.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.095 total time=   3.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.032 total time=   3.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   3.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.151 total time=   7.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.136 total time=   7.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   7.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.488 total time=   6.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.586 total time=   6.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.470 total time=   6.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.451 total time=  14.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.678 total time=  16.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.553 total time=  15.9s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.676 total time=   9.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.737 total time=   9.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.654 total time=   9.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.643 total time=  20.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.776 total time=  19.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.675 total time=  22.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.745 total time=  10.9s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.767 total time=  10.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.699 total time=  10.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.758 total time=  22.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.800 total time=  23.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.692 total time=  23.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.702 total time=   1.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.723 total time=   1.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.682 total time=   1.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.798 total time=   3.1s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.777 total time=   3.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.727 total time=   3.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.310 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.414 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.296 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.378 total time=   1.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.446 total time=   1.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.331 total time=   1.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.583 total time=   1.0s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.685 total time=   1.0s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.588 total time=   0.9s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.596 total time=   2.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.702 total time=   2.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.588 total time=   2.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.663 total time=   1.1s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.717 total time=   1.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.629 total time=   1.1s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.721 total time=   2.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.745 total time=   2.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.708 total time=   2.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.708 total time=   1.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.725 total time=   1.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.669 total time=   1.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.769 total time=   2.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.733 total time=   2.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.751 total time=   2.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.276 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.373 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.213 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.336 total time=   1.0s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.430 total time=   1.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.304 total time=   1.1s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.561 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.655 total time=   0.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.537 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.561 total time=   1.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.673 total time=   1.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.581 total time=   1.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.670 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.706 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.609 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.708 total time=   1.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.723 total time=   1.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=8, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.689 total time=   1.6s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.757 total time=  19.1s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.797 total time=  19.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.725 total time=  19.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.776 total time=  31.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.825 total time=  31.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.767 total time=  36.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.095 total time=   3.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.032 total time=   3.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   3.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.151 total time=   7.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.136 total time=   7.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   7.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.488 total time=   6.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.586 total time=   6.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.470 total time=   6.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.451 total time=  14.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.678 total time=  15.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.553 total time=  15.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.683 total time=   9.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.731 total time=   9.4s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.647 total time=   9.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.650 total time=  20.9s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.778 total time=  19.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.675 total time=  22.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.745 total time=  11.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.776 total time=  11.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.712 total time=  11.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.697 total time=  23.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.800 total time=  23.9s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.735 total time=  27.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.757 total time=   2.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.751 total time=   2.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.699 total time=   2.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.830 total time=   5.1s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.837 total time=   4.6s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.803 total time=   4.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.310 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.414 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.296 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.378 total time=   1.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.446 total time=   1.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.331 total time=   1.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.576 total time=   0.9s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.678 total time=   1.0s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.574 total time=   1.0s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.590 total time=   2.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.696 total time=   2.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.595 total time=   2.0s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.676 total time=   1.1s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.708 total time=   1.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.647 total time=   1.1s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.757 total time=   2.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.749 total time=   2.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.720 total time=   2.4s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.751 total time=   2.3s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.731 total time=   2.3s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.714 total time=   2.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.841 total time=   3.9s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.826 total time=   3.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.783 total time=   3.3s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.276 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.373 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.213 total time=   0.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.336 total time=   1.0s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.430 total time=   1.1s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.304 total time=   1.1s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.554 total time=   0.7s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.648 total time=   0.7s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.537 total time=   0.7s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.576 total time=   1.6s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.690 total time=   1.5s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.581 total time=   1.5s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.689 total time=   0.8s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.710 total time=   0.8s
# [CV 3/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.588 total time=   0.8s
# [CV 1/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.727 total time=   1.9s
# [CV 2/3] END ccp_alpha=0, learning_rate=0.001, loss=log_loss, max_depth=17, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.723 total time=   1.8s
# ...
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.000 total time=  35.2s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.000 total time=  33.4s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.000 total time=  39.4s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   3.3s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   3.3s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   3.3s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   7.2s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   7.3s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   7.2s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.000 total time=   6.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.000 total time=   6.5s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.000 total time=   6.5s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.000 total time=  13.9s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.000 total time=  14.6s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.000 total time=  16.2s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.000 total time=   9.2s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.000 total time=   8.9s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.000 total time=   9.5s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.000 total time=  20.3s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.000 total time=  20.2s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.000 total time=  23.5s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.000 total time=  10.5s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.000 total time=  10.5s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.000 total time=  10.4s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.000 total time=  22.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.000 total time=  22.7s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=None, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.000 total time=  28.4s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.000 total time=   1.2s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.000 total time=   1.3s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.000 total time=   1.3s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.000 total time=   3.5s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.000 total time=   3.4s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.000 total time=   3.2s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.7s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.000 total time=   1.7s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.000 total time=   1.5s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.000 total time=   1.5s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.000 total time=   1.0s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.9s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.000 total time=   1.0s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.000 total time=   2.1s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.000 total time=   2.0s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.000 total time=   2.2s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.000 total time=   1.0s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.000 total time=   1.0s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.000 total time=   1.0s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.000 total time=   2.5s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.000 total time=   2.4s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=sqrt, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.000 total time=   2.3s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.8s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.8s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.8s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.000 total time=   2.2s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.000 total time=   2.1s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=None, n_estimators=220, subsample=1;, score=0.000 total time=   2.1s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.2s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=2, n_estimators=220, subsample=1;, score=0.000 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.000 total time=   1.0s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.000 total time=   1.1s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=7, n_estimators=220, subsample=1;, score=0.000 total time=   1.1s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.7s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.000 total time=   1.4s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.000 total time=   1.4s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=16, n_estimators=220, subsample=1;, score=0.000 total time=   1.4s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.7s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=0.45;, score=0.000 total time=   0.7s
# [CV 1/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.000 total time=   1.6s
# [CV 2/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.000 total time=   1.6s
# [CV 3/3] END ccp_alpha=0.3, learning_rate=0.4, loss=exponential, max_depth=None, max_features=log2, max_leaf_nodes=25, n_estimators=220, subsample=1;, score=0.000 total time=   1.6s

# %%
print('Best score using 3-fold cross validation:', round(opt_gs2.best_score_,2))
# Out:
# Best score using 3-fold cross validation: 0.91

# %%
print('Best parameters using 3-fold cross validation:', opt_gs2.best_params_)
# Out:
# Best parameters using 3-fold cross validation: {'ccp_alpha': 0, 'learning_rate': 0.1, 'loss': 'log_loss', 'max_depth': 8, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'n_estimators': 220, 'subsample': 1}

# %% [markdown]
# But the score was same (upto 2 decimal places) when we extended the search space for parameters which had edge cases selected as best values.

# %% [markdown]
# ### From the cross-validation scores, the best parameters are ones found by Grid Search

# %%
clf = GradientBoostingClassifier(random_state=5000, **opt_gs2.best_params_)
clf
# Out:
# GradientBoostingClassifier(ccp_alpha=0, max_depth=8, max_features='sqrt',
#                            n_estimators=220, random_state=5000, subsample=1)

# %%
clf.fit(X_train_gray_sc, y_train_final)
pred_gray_val = clf.predict(X_test_gray_sc)
calculate_metrics(pred_gray_val, y_test)
# Out:
# Accuracy in detecting Accident class: 0.93
#
# ------------------------------------------------------------------------------------------
#
# +-----------+-----------------------+-------------------+
# | Metric    |   Non-Accident images |   Accident images |
# +===========+=======================+===================+
# | Precision |                  0.9  |              0.98 |
# +-----------+-----------------------+-------------------+
# | Recall    |                  0.98 |              0.87 |
# +-----------+-----------------------+-------------------+
# | f1-score  |                  0.94 |              0.92 |
# +-----------+-----------------------+-------------------+
#
# ------------------------------------------------------------------------------------------
#
# Sensitivity/ ability to correctly classifiy to Accident class is: 0.87
# Specificity/ ability to correctly classifiy to Non-Accident class is: 0.98
#
# ------------------------------------------------------------------------------------------
#
# Fbeta score with beta = 1.5 is: 0.9
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
#
# AUC score is: 0.93

# %% [markdown]
# So, the best we could do using **Gradient Boosting Algorithms** is a test set fbeta score (beta = 1.4) of 0.9, with the parameters:
#
# - random_state = 5000
# - 'ccp_alpha': 0,
# - 'learning_rate': 0.1,
# - 'loss': 'log_loss'
# - 'max_depth': 8
# - 'max_features': 'sqrt'
# - 'max_leaf_nodes': None
# - 'n_estimators': 220
# - 'subsample': 1
